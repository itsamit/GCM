# %% [markdown]
# Reconstruction of pairwise community model-
# GCM_P1_P2

# %%
import cobra
import sys
import os

# %%
##1Reconstruction of pairwise community model- GCM_P1_P2##

model1 = cobra.io.read_sbml_model(r'Final_GEM/ksp_P2.xml') #Uploading Individual GEM#
model2 = cobra.io.read_sbml_model(r'Final_GEM/ml_P1.xml') 

print(len(model1.reactions))
print(len(model1.metabolites))
print(len(model1.genes))

#optimising the value#
solution=model1.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model1)

print(len(model2.reactions))
print(len(model2.metabolites))
print(len(model2.genes))

#optimising the value#
solution=model2.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model2)####use Jupyter notebook##

for i in model1.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"ksp"
        i.id=j
        i.compartment="c0ksp"

for i in model2.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"ml"
        i.id=j
        i.compartment="c0ml"

count=0
for i in model1.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"ksp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"ml"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"ksp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"ml"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"ksp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"ml"
        i.id=j
        count=count+1
print(count)

from cobra import Model, Reaction, Metabolite
model = Model('community_model8')
count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model1.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model2.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

from cobra import Metabolite
cpd11416_c0 = Metabolite(
    'cpd11416_c0',
    name='Complete_Biomass',
    compartment='c0'

    )

from cobra import Metabolite
cpd11416_b = Metabolite(
    'cpd11416_b',
    name='Complete_Biomass',
    compartment='e0'
    )

reaction = Reaction('Bio1')
reaction.name = ('Community_biomass')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({model1.metabolites.get_by_id("cpd11416_c0ksp"): -0.43,
                          model2.metabolites.get_by_id("cpd11416_c0ml"): -0.57,
                          cpd11416_c0: 1
                         })

        
reaction.reaction
model.add_reactions([reaction])
print(count)

reaction = Reaction('EX_cpd11416_c0')
reaction.name = ('EX_cpd11416_c0')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({
                          model.metabolites.get_by_id("cpd11416_c0"): -1,
                          cpd11416_b: 1
                        })

        
reaction.reaction
model.add_reactions([reaction])

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

model.objective = 'Bio1'

print('Community model has been reconstructed')
print('Model objective Bio1: ', model.slim_optimize())



cobra.io.write_sbml_model(model,'Output_GCM/GCM_P1_P2.xml')

F = model.optimize()
flux_p1_p2=F.fluxes
flux_p1_p2.to_csv("Output_FBA/FBA_p1_p2.csv")
# Out:
# 1757
# 1824
# 1996
# 1120
# 1203
# 1172
# 1561
# 1031
# 1
# 1
# 3
# 0
# Ignoring reaction 'EX_cpd11416_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_b' since it already exists.
# Ignoring reaction 'EX_cpd00001_b' since it already exists.
# Ignoring reaction 'EX_cpd00058_b' since it already exists.
# Ignoring reaction 'EX_cpd00051_b' since it already exists.
# Ignoring reaction 'EX_cpd00100_b' since it already exists.
# Ignoring reaction 'EX_cpd00060_b' since it already exists.
# Ignoring reaction 'EX_cpd00034_b' since it already exists.
# Ignoring reaction 'EX_cpd00027_b' since it already exists.
# Ignoring reaction 'EX_cpd00035_b' since it already exists.
# Ignoring reaction 'EX_cpd00254_b' since it already exists.
# Ignoring reaction 'EX_cpd00039_b' since it already exists.
# Ignoring reaction 'EX_cpd00009_b' since it already exists.
# Ignoring reaction 'EX_cpd00129_b' since it already exists.
# Ignoring reaction 'EX_cpd10516_b' since it already exists.
# Ignoring reaction 'EX_cpd00149_b' since it already exists.
# Ignoring reaction 'EX_cpd00226_b' since it already exists.
# Ignoring reaction 'EX_cpd00048_b' since it already exists.
# Ignoring reaction 'EX_cpd00007_b' since it already exists.
# Ignoring reaction 'EX_cpd00011_b' since it already exists.
# Ignoring reaction 'EX_cpd00099_b' since it already exists.
# Ignoring reaction 'EX_cpd00063_b' since it already exists.
# Ignoring reaction 'EX_cpd00030_b' since it already exists.
# Ignoring reaction 'EX_cpd00205_b' since it already exists.
# 1756
# Ignoring reaction 'EX_cpd00067_e0' since it already exists.
# Ignoring reaction 'EX_cpd11576_e0' since it already exists.
# Ignoring reaction 'EX_cpd04097_e0' since it already exists.
# Ignoring reaction 'EX_cpd00012_e0' since it already exists.
# Ignoring reaction 'EX_cpd01012_e0' since it already exists.
# Ignoring reaction 'EX_cpd00001_e0' since it already exists.
# Ignoring reaction 'EX_cpd00023_e0' since it already exists.
# Ignoring reaction 'EX_cpd00971_e0' since it already exists.
# Ignoring reaction 'EX_cpd00058_e0' since it already exists.
# Ignoring reaction 'EX_cpd00013_e0' since it already exists.
# Ignoring reaction 'EX_cpd00051_e0' since it already exists.
# Ignoring reaction 'EX_cpd00064_e0' since it already exists.
# Ignoring reaction 'EX_cpd00244_e0' since it already exists.
# Ignoring reaction 'EX_cpd11578_e0' since it already exists.
# Ignoring reaction 'EX_cpd00100_e0' since it already exists.
# Ignoring reaction 'EX_cpd00060_e0' since it already exists.
# Ignoring reaction 'EX_cpd00034_e0' since it already exists.
# Ignoring reaction 'EX_cpd00027_e0' since it already exists.
# Ignoring reaction 'EX_cpd11579_e0' since it already exists.
# Ignoring reaction 'EX_cpd00210_e0' since it already exists.
# Ignoring reaction 'EX_cpd00637_e0' since it already exists.
# Ignoring reaction 'EX_cpd00035_e0' since it already exists.
# Ignoring reaction 'EX_cpd00117_e0' since it already exists.
# Ignoring reaction 'EX_cpd00254_e0' since it already exists.
# Ignoring reaction 'EX_cpd00159_e0' since it already exists.
# Ignoring reaction 'EX_cpd03048_e0' since it already exists.
# Ignoring reaction 'EX_cpd11596_e0' since it already exists.
# Ignoring reaction 'EX_cpd00039_e0' since it already exists.
# Ignoring reaction 'EX_cpd00009_e0' since it already exists.
# Ignoring reaction 'EX_cpd00129_e0' since it already exists.
# Ignoring reaction 'EX_cpd10516_e0' since it already exists.
# Ignoring reaction 'EX_cpd00149_e0' since it already exists.
# Ignoring reaction 'EX_cpd01914_e0' since it already exists.
# Ignoring reaction 'EX_cpd00531_e0' since it already exists.
# Ignoring reaction 'EX_cpd00395_e0' since it already exists.
# Ignoring reaction 'EX_cpd00138_e0' since it already exists.
# Ignoring reaction 'EX_cpd11575_e0' since it already exists.
# Ignoring reaction 'EX_cpd00226_e0' since it already exists.
# Ignoring reaction 'EX_cpd09878_e0' since it already exists.
# Ignoring reaction 'EX_cpd00048_e0' since it already exists.
# Ignoring reaction 'EX_cpd00007_e0' since it already exists.
# Ignoring reaction 'EX_cpd08023_e0' since it already exists.
# Ignoring reaction 'EX_cpd00305_e0' since it already exists.
# Ignoring reaction 'EX_cpd00011_e0' since it already exists.
# Ignoring reaction 'EX_cpd00099_e0' since it already exists.
# Ignoring reaction 'EX_cpd00063_e0' since it already exists.
# Ignoring reaction 'EX_cpd00030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00205_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_b' since it already exists.
# 1119
# 2801
# 2926
# 1583
# 1119
# 2803
# 2927
# 1583
# Model objective Bio1:  0.3408245415634745
# Community model has been reconstructed

# %% [markdown]
# Reconstruction of pairwise community model-
# GCM_P1_P3

# %%
##2Reconstruction of pairwise community model- GCM_P1_P3##


model1 = cobra.io.read_sbml_model(r'Final_GEM/ml_P1.xml') #Uploading Individual GEM#
model2 = cobra.io.read_sbml_model(r'Final_GEM/csp_P3.xml')

print(len(model1.reactions))
print(len(model1.metabolites))
print(len(model1.genes))

#optimising the value#
solution=model1.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model1)

print(len(model2.reactions))
print(len(model2.metabolites))
print(len(model2.genes))

#optimising the value#
solution=model2.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model2)####use Jupyter notebook##


for i in model1.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"ml"
        i.id=j
        i.compartment="c0ml"

for i in model2.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"csp"
        i.id=j
        i.compartment="c0csp"

count=0
for i in model1.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"ml"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"csp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"ml"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"csp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"ml"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"csp"
        i.id=j
        count=count+1
print(count)

from cobra import Model, Reaction, Metabolite
model = Model('community_model3')
count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model1.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model2.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

from cobra import Metabolite
cpd11416_c0 = Metabolite(
    'cpd11416_c0',
    name='Complete_Biomass',
    compartment='c0'

    )

from cobra import Metabolite
cpd11416_b = Metabolite(
    'cpd11416_b',
    name='Complete_Biomass',
    compartment='e0'
    )

reaction = Reaction('Bio1')
reaction.name = ('Community_biomass')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({model1.metabolites.get_by_id("cpd11416_c0ml"): -0.69,
                          model2.metabolites.get_by_id("cpd11416_c0csp"): -0.31,
                          cpd11416_c0: 1
                         })

        
reaction.reaction
model.add_reactions([reaction])
print(count)

reaction = Reaction('EX_cpd11416_c0')
reaction.name = ('EX_cpd11416_c0')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({
                          model.metabolites.get_by_id("cpd11416_c0"): -1,
                          cpd11416_b: 1
                        })

        
reaction.reaction
model.add_reactions([reaction])

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

model.objective = 'Bio1'
print('Community model has been reconstructed')
print('Model objective Bio1: ', model.slim_optimize())

cobra.io.write_sbml_model(model,'Output_GCM/GCM_P1_P3.xml')

#Flux Balance Analysis#
F = model.optimize()
flux_p1_p3=F.fluxes
flux_p1_p3.to_csv("Output_FBA/FBA_p1_p3.csv")
# Out:
# 1120
# 1203
# 1172
# 1260
# 1329
# 1242
# 1031
# 1181
# 1
# 1
# 0
# 2
# Ignoring reaction 'EX_cpd11416_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_b' since it already exists.
# Ignoring reaction 'EX_cpd00001_b' since it already exists.
# Ignoring reaction 'EX_cpd00058_b' since it already exists.
# Ignoring reaction 'EX_cpd00013_b' since it already exists.
# Ignoring reaction 'EX_cpd00051_b' since it already exists.
# Ignoring reaction 'EX_cpd00064_b' since it already exists.
# Ignoring reaction 'EX_cpd00100_b' since it already exists.
# Ignoring reaction 'EX_cpd00034_b' since it already exists.
# Ignoring reaction 'EX_cpd10516_b' since it already exists.
# Ignoring reaction 'EX_cpd00027_b' since it already exists.
# Ignoring reaction 'EX_cpd00254_b' since it already exists.
# Ignoring reaction 'EX_cpd00205_b' since it already exists.
# Ignoring reaction 'EX_cpd00048_b' since it already exists.
# Ignoring reaction 'EX_cpd00030_b' since it already exists.
# Ignoring reaction 'EX_cpd00149_b' since it already exists.
# Ignoring reaction 'EX_cpd00226_b' since it already exists.
# Ignoring reaction 'EX_cpd00007_b' since it already exists.
# Ignoring reaction 'EX_cpd00011_b' since it already exists.
# Ignoring reaction 'EX_cpd00063_b' since it already exists.
# Ignoring reaction 'EX_cpd00009_b' since it already exists.
# Ignoring reaction 'EX_cpd00099_b' since it already exists.
# 1119
# Ignoring reaction 'EX_cpd00067_e0' since it already exists.
# Ignoring reaction 'EX_cpd04097_e0' since it already exists.
# Ignoring reaction 'EX_cpd01012_e0' since it already exists.
# Ignoring reaction 'EX_cpd00001_e0' since it already exists.
# Ignoring reaction 'EX_cpd00023_e0' since it already exists.
# Ignoring reaction 'EX_cpd00971_e0' since it already exists.
# Ignoring reaction 'EX_cpd00058_e0' since it already exists.
# Ignoring reaction 'EX_cpd00013_e0' since it already exists.
# Ignoring reaction 'EX_cpd00051_e0' since it already exists.
# Ignoring reaction 'EX_cpd00064_e0' since it already exists.
# Ignoring reaction 'EX_cpd00100_e0' since it already exists.
# Ignoring reaction 'EX_cpd00034_e0' since it already exists.
# Ignoring reaction 'EX_cpd10516_e0' since it already exists.
# Ignoring reaction 'EX_cpd00027_e0' since it already exists.
# Ignoring reaction 'EX_cpd00254_e0' since it already exists.
# Ignoring reaction 'EX_cpd00205_e0' since it already exists.
# Ignoring reaction 'EX_cpd00138_e0' since it already exists.
# Ignoring reaction 'EX_cpd00048_e0' since it already exists.
# Ignoring reaction 'EX_cpd00030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00149_e0' since it already exists.
# Ignoring reaction 'EX_cpd00531_e0' since it already exists.
# Ignoring reaction 'EX_cpd00226_e0' since it already exists.
# Ignoring reaction 'EX_cpd00104_e0' since it already exists.
# Ignoring reaction 'EX_cpd00007_e0' since it already exists.
# Ignoring reaction 'EX_cpd00305_e0' since it already exists.
# Ignoring reaction 'EX_cpd00011_e0' since it already exists.
# Ignoring reaction 'EX_cpd00063_e0' since it already exists.
# Ignoring reaction 'EX_cpd00009_e0' since it already exists.
# Ignoring reaction 'EX_cpd00099_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_b' since it already exists.
# 1259
# 2325
# 2469
# 1206
# 1259
# 2327
# 2470
# 1206

# %% [markdown]
# Reconstruction of pairwise community model- GCM_P1_P4

# %%
##3Reconstruction of pairwise community model- GCM_P1_P4##

model1 = cobra.io.read_sbml_model(r'Final_GEM/ml_P1.xml') #Uploading Individual GEM#
model2 = cobra.io.read_sbml_model(r'Final_GEM/osp_P4.xml')

print(len(model1.reactions))
print(len(model1.metabolites))
print(len(model1.genes))

#optimising the value#
solution=model1.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model1)

print(len(model2.reactions))
print(len(model2.metabolites))
print(len(model2.genes))

#optimising the value#
solution=model2.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model2)####use Jupyter notebook##


for i in model1.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"ml"
        i.id=j
        i.compartment="c0oml"

for i in model2.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"osp"
        i.id=j
        i.compartment="c0osp"

count=0
for i in model1.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"ml"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"osp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"ml"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"osp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"ml"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"osp"
        i.id=j
        count=count+1
print(count)

from cobra import Model, Reaction, Metabolite
model = Model('community_model7')
count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model1.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model2.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

from cobra import Metabolite
cpd11416_c0 = Metabolite(
    'cpd11416_c0',
    name='Complete_Biomass',
    compartment='c0'

    )

from cobra import Metabolite
cpd11416_b = Metabolite(
    'cpd11416_b',
    name='Complete_Biomass',
    compartment='e0'
    )

reaction = Reaction('Bio1')
reaction.name = ('Community_biomass')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({model1.metabolites.get_by_id("cpd11416_c0ml"): -0.73,
                          model2.metabolites.get_by_id("cpd11416_c0osp"): -0.27,
                          cpd11416_c0: 1
                         })

        
reaction.reaction
model.add_reactions([reaction])
print(count)

reaction = Reaction('EX_cpd11416_c0')
reaction.name = ('EX_cpd11416_c0')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({
                          model.metabolites.get_by_id("cpd11416_c0"): -1,
                          cpd11416_b: 1
                        })

        
reaction.reaction
model.add_reactions([reaction])

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

model.objective = 'Bio1'
print('Community model has been reconstructed')
print('Model objective Bio1: ', model.slim_optimize())

cobra.io.write_sbml_model(model,'Output_GCM/GCM_P1_P4.xml')


F = model.optimize()
flux_p1_p4=F.fluxes
flux_p1_p4.to_csv("Output_FBA/FBA_p1_p4.csv")
# Out:
# 1120
# 1203
# 1172
# 1559
# 1594
# 2446
# 1031
# 1361
# 1
# 1
# 0
# 3
# Ignoring reaction 'EX_cpd11416_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_b' since it already exists.
# Ignoring reaction 'EX_cpd00129_b' since it already exists.
# Ignoring reaction 'EX_cpd00001_b' since it already exists.
# Ignoring reaction 'EX_cpd00058_b' since it already exists.
# Ignoring reaction 'EX_cpd00051_b' since it already exists.
# Ignoring reaction 'EX_cpd00064_b' since it already exists.
# Ignoring reaction 'EX_cpd00100_b' since it already exists.
# Ignoring reaction 'EX_cpd00009_b' since it already exists.
# Ignoring reaction 'EX_cpd00034_b' since it already exists.
# Ignoring reaction 'EX_cpd00254_b' since it already exists.
# Ignoring reaction 'EX_cpd00142_b' since it already exists.
# Ignoring reaction 'EX_cpd10516_b' since it already exists.
# Ignoring reaction 'EX_cpd00149_b' since it already exists.
# Ignoring reaction 'EX_cpd00027_b' since it already exists.
# Ignoring reaction 'EX_cpd00226_b' since it already exists.
# Ignoring reaction 'EX_cpd00048_b' since it already exists.
# Ignoring reaction 'EX_cpd00007_b' since it already exists.
# Ignoring reaction 'EX_cpd00039_b' since it already exists.
# Ignoring reaction 'EX_cpd00011_b' since it already exists.
# Ignoring reaction 'EX_cpd00030_b' since it already exists.
# Ignoring reaction 'EX_cpd00013_b' since it already exists.
# Ignoring reaction 'EX_cpd00205_b' since it already exists.
# Ignoring reaction 'EX_cpd00099_b' since it already exists.
# Ignoring reaction 'EX_cpd00063_b' since it already exists.
# 1119
# Ignoring reaction 'EX_cpd00067_e0' since it already exists.
# Ignoring reaction 'EX_cpd00073_e0' since it already exists.
# Ignoring reaction 'EX_cpd11576_e0' since it already exists.
# Ignoring reaction 'EX_cpd04097_e0' since it already exists.
# Ignoring reaction 'EX_cpd11597_e0' since it already exists.
# Ignoring reaction 'EX_cpd00129_e0' since it already exists.
# Ignoring reaction 'EX_cpd00971_e0' since it already exists.
# Ignoring reaction 'EX_cpd01012_e0' since it already exists.
# Ignoring reaction 'EX_cpd00001_e0' since it already exists.
# Ignoring reaction 'EX_cpd00023_e0' since it already exists.
# Ignoring reaction 'EX_cpd00058_e0' since it already exists.
# Ignoring reaction 'EX_cpd00797_e0' since it already exists.
# Ignoring reaction 'EX_cpd00051_e0' since it already exists.
# Ignoring reaction 'EX_cpd00064_e0' since it already exists.
# Ignoring reaction 'EX_cpd11578_e0' since it already exists.
# Ignoring reaction 'EX_cpd00100_e0' since it already exists.
# Ignoring reaction 'EX_cpd00009_e0' since it already exists.
# Ignoring reaction 'EX_cpd00060_e0' since it already exists.
# Ignoring reaction 'EX_cpd00034_e0' since it already exists.
# Ignoring reaction 'EX_cpd11579_e0' since it already exists.
# Ignoring reaction 'EX_cpd00210_e0' since it already exists.
# Ignoring reaction 'EX_cpd00637_e0' since it already exists.
# Ignoring reaction 'EX_cpd00254_e0' since it already exists.
# Ignoring reaction 'EX_cpd00138_e0' since it already exists.
# Ignoring reaction 'EX_cpd00305_e0' since it already exists.
# Ignoring reaction 'EX_cpd00142_e0' since it already exists.
# Ignoring reaction 'EX_cpd00211_e0' since it already exists.
# Ignoring reaction 'EX_cpd03048_e0' since it already exists.
# Ignoring reaction 'EX_cpd11596_e0' since it already exists.
# Ignoring reaction 'EX_cpd00540_e0' since it already exists.
# Ignoring reaction 'EX_cpd10516_e0' since it already exists.
# Ignoring reaction 'EX_cpd00149_e0' since it already exists.
# Ignoring reaction 'EX_cpd01914_e0' since it already exists.
# Ignoring reaction 'EX_cpd00531_e0' since it already exists.
# Ignoring reaction 'EX_cpd00395_e0' since it already exists.
# Ignoring reaction 'EX_cpd00027_e0' since it already exists.
# Ignoring reaction 'EX_cpd11575_e0' since it already exists.
# Ignoring reaction 'EX_cpd00226_e0' since it already exists.
# Ignoring reaction 'EX_cpd09878_e0' since it already exists.
# Ignoring reaction 'EX_cpd00048_e0' since it already exists.
# Ignoring reaction 'EX_cpd00104_e0' since it already exists.
# Ignoring reaction 'EX_cpd00007_e0' since it already exists.
# Ignoring reaction 'EX_cpd00098_e0' since it already exists.
# Ignoring reaction 'EX_cpd08023_e0' since it already exists.
# Ignoring reaction 'EX_cpd00039_e0' since it already exists.
# Ignoring reaction 'EX_cpd00011_e0' since it already exists.
# Ignoring reaction 'EX_cpd00030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00013_e0' since it already exists.
# Ignoring reaction 'EX_cpd00205_e0' since it already exists.
# Ignoring reaction 'EX_cpd00099_e0' since it already exists.
# Ignoring reaction 'EX_cpd00063_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_b' since it already exists.
# 1558
# 2599
# 2690
# 1808
# 1558
# 2601
# 2691
# 1808

# %% [markdown]
# Reconstruction of pairwise community model- GCM_P1_P5

# %%
##4Reconstruction of pairwise community model- GCM_P1_P5##


model1 = cobra.io.read_sbml_model(r'Final_GEM/bsp_P5.xml')
model2 = cobra.io.read_sbml_model(r'Final_GEM/ml_P1.xml')

print(len(model1.reactions))
print(len(model1.metabolites))
print(len(model1.genes))

#optimising the value#
solution=model1.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model1)

print(len(model2.reactions))
print(len(model2.metabolites))
print(len(model2.genes))

#optimising the value#
solution=model2.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model2)####use Jupyter notebook##


for i in model1.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"bsp"
        i.id=j
        i.compartment="c0bsp"

for i in model2.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"ml"
        i.id=j
        i.compartment="c0ml"

count=0
for i in model1.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"bsp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"ml"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"bsp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"ml"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"bsp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"ml"
        i.id=j
        count=count+1
print(count)

from cobra import Model, Reaction, Metabolite
model = Model('community_model9')
count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model1.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model2.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

from cobra import Metabolite
cpd11416_c0 = Metabolite(
    'cpd11416_c0',
    name='Complete_Biomass',
    compartment='c0'

    )

from cobra import Metabolite
cpd11416_b = Metabolite(
    'cpd11416_b',
    name='Complete_Biomass',
    compartment='e0'
    )

reaction = Reaction('Bio1')
reaction.name = ('Community_biomass')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({model1.metabolites.get_by_id("cpd11416_c0bsp"): -0.513,
                          model2.metabolites.get_by_id("cpd11416_c0ml"): -0.487,
                          cpd11416_c0: 1
                         })

        
reaction.reaction
model.add_reactions([reaction])
print(count)

reaction = Reaction('EX_cpd11416_c0')
reaction.name = ('EX_cpd11416_c0')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({
                          model.metabolites.get_by_id("cpd11416_c0"): -1,
                          cpd11416_b: 1
                        })

        
reaction.reaction
model.add_reactions([reaction])

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

model.objective = 'Bio1'

print('Community model has been reconstructed')
print('Model objective Bio1: ', model.slim_optimize())
cobra.io.write_sbml_model(model,'Output_GCM/GCM_P1_P5.xml')

F = model.optimize()
flux_p1_p5=F.fluxes
flux_p1_p5.to_csv("Output_FBA/FBA_p1_p5.csv")
# Out:
# 1489
# 1500
# 1562
# 1120
# 1203
# 1172
# 1312
# 1031
# 1
# 1
# 1
# 0
# Ignoring reaction 'EX_cpd11416_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_b' since it already exists.
# Ignoring reaction 'EX_cpd00001_b' since it already exists.
# Ignoring reaction 'EX_cpd00058_b' since it already exists.
# Ignoring reaction 'EX_cpd00013_b' since it already exists.
# Ignoring reaction 'EX_cpd00051_b' since it already exists.
# Ignoring reaction 'EX_cpd00064_b' since it already exists.
# Ignoring reaction 'EX_cpd00100_b' since it already exists.
# Ignoring reaction 'EX_cpd00060_b' since it already exists.
# Ignoring reaction 'EX_cpd00034_b' since it already exists.
# Ignoring reaction 'EX_cpd00027_b' since it already exists.
# Ignoring reaction 'EX_cpd00035_b' since it already exists.
# Ignoring reaction 'EX_cpd00117_b' since it already exists.
# Ignoring reaction 'EX_cpd00254_b' since it already exists.
# Ignoring reaction 'EX_cpd00039_b' since it already exists.
# Ignoring reaction 'EX_cpd00009_b' since it already exists.
# Ignoring reaction 'EX_cpd10516_b' since it already exists.
# Ignoring reaction 'EX_cpd00149_b' since it already exists.
# Ignoring reaction 'EX_cpd00226_b' since it already exists.
# Ignoring reaction 'EX_cpd00048_b' since it already exists.
# Ignoring reaction 'EX_cpd00007_b' since it already exists.
# Ignoring reaction 'EX_cpd00011_b' since it already exists.
# Ignoring reaction 'EX_cpd00099_b' since it already exists.
# Ignoring reaction 'EX_cpd00063_b' since it already exists.
# Ignoring reaction 'EX_cpd00030_b' since it already exists.
# Ignoring reaction 'EX_cpd00205_b' since it already exists.
# 1488
# Ignoring reaction 'EX_cpd00067_e0' since it already exists.
# Ignoring reaction 'EX_cpd11576_e0' since it already exists.
# Ignoring reaction 'EX_cpd04097_e0' since it already exists.
# Ignoring reaction 'EX_cpd00012_e0' since it already exists.
# Ignoring reaction 'EX_cpd01012_e0' since it already exists.
# Ignoring reaction 'EX_cpd00001_e0' since it already exists.
# Ignoring reaction 'EX_cpd00023_e0' since it already exists.
# Ignoring reaction 'EX_cpd00971_e0' since it already exists.
# Ignoring reaction 'EX_cpd00058_e0' since it already exists.
# Ignoring reaction 'EX_cpd00797_e0' since it already exists.
# Ignoring reaction 'EX_cpd00013_e0' since it already exists.
# Ignoring reaction 'EX_cpd00051_e0' since it already exists.
# Ignoring reaction 'EX_cpd00064_e0' since it already exists.
# Ignoring reaction 'EX_cpd00100_e0' since it already exists.
# Ignoring reaction 'EX_cpd00060_e0' since it already exists.
# Ignoring reaction 'EX_cpd00034_e0' since it already exists.
# Ignoring reaction 'EX_cpd00027_e0' since it already exists.
# Ignoring reaction 'EX_cpd00637_e0' since it already exists.
# Ignoring reaction 'EX_cpd00035_e0' since it already exists.
# Ignoring reaction 'EX_cpd00117_e0' since it already exists.
# Ignoring reaction 'EX_cpd00254_e0' since it already exists.
# Ignoring reaction 'EX_cpd00039_e0' since it already exists.
# Ignoring reaction 'EX_cpd00009_e0' since it already exists.
# Ignoring reaction 'EX_cpd10516_e0' since it already exists.
# Ignoring reaction 'EX_cpd00149_e0' since it already exists.
# Ignoring reaction 'EX_cpd01914_e0' since it already exists.
# Ignoring reaction 'EX_cpd00531_e0' since it already exists.
# Ignoring reaction 'EX_cpd00138_e0' since it already exists.
# Ignoring reaction 'EX_cpd00226_e0' since it already exists.
# Ignoring reaction 'EX_cpd00048_e0' since it already exists.
# Ignoring reaction 'EX_cpd00104_e0' since it already exists.
# Ignoring reaction 'EX_cpd00007_e0' since it already exists.
# Ignoring reaction 'EX_cpd00011_e0' since it already exists.
# Ignoring reaction 'EX_cpd00099_e0' since it already exists.
# Ignoring reaction 'EX_cpd00063_e0' since it already exists.
# Ignoring reaction 'EX_cpd00030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00205_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_b' since it already exists.
# 1119
# 2542
# 2624
# 1366
# 1119
# 2544
# 2625
# 1366

# %% [markdown]
# Reconstruction of pairwise community model- GCM_P1_P6

# %%
##5Reconstruction of pairwise community model- GCM_P1_P6##

import cobra
import sys
import os

model1 = cobra.io.read_sbml_model(r'Final_GEM/ml_P1.xml')
model2 = cobra.io.read_sbml_model(r'Final_GEM/nc_P6.xml')

print(len(model1.reactions))
print(len(model1.metabolites))
print(len(model1.genes))

#optimising the value#
solution=model1.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model1)

print(len(model2.reactions))
print(len(model2.metabolites))
print(len(model2.genes))

#optimising the value#
solution=model2.optimize()
solution.objective_value


cobra.flux_analysis.find_blocked_reactions(model2)####use Jupyter notebook##


for i in model1.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"ml"
        i.id=j
        i.compartment="c0ml"

for i in model2.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"nc"
        i.id=j
        i.compartment="c0nc"

count=0
for i in model1.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"ml"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"nc"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"ml"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"nc"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"ml"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"nc"
        i.id=j
        count=count+1
print(count)

from cobra import Model, Reaction, Metabolite
model = Model('community_model4')
count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model1.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model2.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

from cobra import Metabolite
cpd11416_c0 = Metabolite(
    'cpd11416_c0',
    name='Complete_Biomass',
    compartment='c0'

    )

from cobra import Metabolite
cpd11416_b = Metabolite(
    'cpd11416_b',
    name='Complete_Biomass',
    compartment='e0'
    )

reaction = Reaction('Bio1')
reaction.name = ('Community_biomass')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({model1.metabolites.get_by_id("cpd11416_c0ml"): -0.625,
                          model2.metabolites.get_by_id("cpd11416_c0nc"): -0.375,
                          cpd11416_c0: 1
                         })

        
reaction.reaction
model.add_reactions([reaction])
print(count)

reaction = Reaction('EX_cpd11416_c0')
reaction.name = ('EX_cpd11416_c0')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({
                          model.metabolites.get_by_id("cpd11416_c0"): -1,
                          cpd11416_b: 1
                        })

        
reaction.reaction
model.add_reactions([reaction])

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

model.objective = 'Bio1'

print('Community model has been reconstructed')
print('Model objective Bio1: ', model.slim_optimize())
cobra.io.write_sbml_model(model,'Output_GCM/GCM_P1_P6.xml')

F = model.optimize()
flux_p1_p6=F.fluxes
flux_p1_p6.to_csv("Output_FBA/FBA_p1_p6.csv")
# Out:
# 1120
# 1203
# 1172
# 1577
# 1563
# 1942
# 1031
# 1366
# 1
# 1
# 0
# 2
# Ignoring reaction 'EX_cpd11416_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_b' since it already exists.
# Ignoring reaction 'EX_cpd00001_b' since it already exists.
# Ignoring reaction 'EX_cpd00058_b' since it already exists.
# Ignoring reaction 'EX_cpd00013_b' since it already exists.
# Ignoring reaction 'EX_cpd00051_b' since it already exists.
# Ignoring reaction 'EX_cpd00064_b' since it already exists.
# Ignoring reaction 'EX_cpd00100_b' since it already exists.
# Ignoring reaction 'EX_cpd00060_b' since it already exists.
# Ignoring reaction 'EX_cpd00035_b' since it already exists.
# Ignoring reaction 'EX_cpd00117_b' since it already exists.
# Ignoring reaction 'EX_cpd00254_b' since it already exists.
# Ignoring reaction 'EX_cpd00159_b' since it already exists.
# Ignoring reaction 'EX_cpd00009_b' since it already exists.
# Ignoring reaction 'EX_cpd10516_b' since it already exists.
# Ignoring reaction 'EX_cpd00030_b' since it already exists.
# Ignoring reaction 'EX_cpd00149_b' since it already exists.
# Ignoring reaction 'EX_cpd00027_b' since it already exists.
# Ignoring reaction 'EX_cpd00226_b' since it already exists.
# Ignoring reaction 'EX_cpd00048_b' since it already exists.
# Ignoring reaction 'EX_cpd00007_b' since it already exists.
# Ignoring reaction 'EX_cpd00205_b' since it already exists.
# 1119
# Ignoring reaction 'EX_cpd00039_b' since it already exists.
# Ignoring reaction 'EX_cpd00011_b' since it already exists.
# Ignoring reaction 'EX_cpd00063_b' since it already exists.
# Ignoring reaction 'EX_cpd00034_b' since it already exists.
# Ignoring reaction 'EX_cpd00099_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_e0' since it already exists.
# Ignoring reaction 'EX_cpd11576_e0' since it already exists.
# Ignoring reaction 'EX_cpd04097_e0' since it already exists.
# Ignoring reaction 'EX_cpd11597_e0' since it already exists.
# Ignoring reaction 'EX_cpd00012_e0' since it already exists.
# Ignoring reaction 'EX_cpd01012_e0' since it already exists.
# Ignoring reaction 'EX_cpd00001_e0' since it already exists.
# Ignoring reaction 'EX_cpd00058_e0' since it already exists.
# Ignoring reaction 'EX_cpd00013_e0' since it already exists.
# Ignoring reaction 'EX_cpd00051_e0' since it already exists.
# Ignoring reaction 'EX_cpd00064_e0' since it already exists.
# Ignoring reaction 'EX_cpd00100_e0' since it already exists.
# Ignoring reaction 'EX_cpd00060_e0' since it already exists.
# Ignoring reaction 'EX_cpd00637_e0' since it already exists.
# Ignoring reaction 'EX_cpd00035_e0' since it already exists.
# Ignoring reaction 'EX_cpd00117_e0' since it already exists.
# Ignoring reaction 'EX_cpd00254_e0' since it already exists.
# Ignoring reaction 'EX_cpd00138_e0' since it already exists.
# Ignoring reaction 'EX_cpd00305_e0' since it already exists.
# Ignoring reaction 'EX_cpd00159_e0' since it already exists.
# Ignoring reaction 'EX_cpd00540_e0' since it already exists.
# Ignoring reaction 'EX_cpd00009_e0' since it already exists.
# Ignoring reaction 'EX_cpd10516_e0' since it already exists.
# Ignoring reaction 'EX_cpd00971_e0' since it already exists.
# Ignoring reaction 'EX_cpd00030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00149_e0' since it already exists.
# Ignoring reaction 'EX_cpd01914_e0' since it already exists.
# Ignoring reaction 'EX_cpd00531_e0' since it already exists.
# Ignoring reaction 'EX_cpd00027_e0' since it already exists.
# Ignoring reaction 'EX_cpd00226_e0' since it already exists.
# Ignoring reaction 'EX_cpd00048_e0' since it already exists.
# Ignoring reaction 'EX_cpd00104_e0' since it already exists.
# Ignoring reaction 'EX_cpd00007_e0' since it already exists.
# Ignoring reaction 'EX_cpd00205_e0' since it already exists.
# Ignoring reaction 'EX_cpd00039_e0' since it already exists.
# Ignoring reaction 'EX_cpd00011_e0' since it already exists.
# Ignoring reaction 'EX_cpd00063_e0' since it already exists.
# Ignoring reaction 'EX_cpd00034_e0' since it already exists.
# Ignoring reaction 'EX_cpd00099_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_b' since it already exists.
# 1576
# 2627
# 2683
# 1556
# 1576
# 2629
# 2684
# 1556

# %% [markdown]
# Reconstruction of pairwise community model- GCM_P2_P3

# %%
##6Reconstruction of pairwise community model- GCM_P2_P3##


model1 = cobra.io.read_sbml_model(r'Final_GEM/ksp_P2.xml')
model2 = cobra.io.read_sbml_model(r'Final_GEM/csp_P3.xml')

print(len(model1.reactions))
print(len(model1.metabolites))
print(len(model1.genes))

#optimising the value#
solution=model1.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model1)

print(len(model2.reactions))
print(len(model2.metabolites))
print(len(model2.genes))

#optimising the value#
solution=model2.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model2)####use Jupyter notebook##


for i in model1.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"ksp"
        i.id=j
        i.compartment="c0ksp"

for i in model2.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"csp"
        i.id=j
        i.compartment="c0csp"

count=0
for i in model1.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"ksp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"csp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"ksp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"csp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"ksp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"csp"
        i.id=j
        count=count+1
print(count)

from cobra import Model, Reaction, Metabolite
model = Model('community_model2')
count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model1.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model2.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

from cobra import Metabolite
cpd11416_c0 = Metabolite(
    'cpd11416_c0',
    name='Complete_Biomass',
    compartment='c0'

    )

from cobra import Metabolite
cpd11416_b = Metabolite(
    'cpd11416_b',
    name='Complete_Biomass',
    compartment='e0'
    )

reaction = Reaction('Bio1')
reaction.name = ('Community_biomass')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({model1.metabolites.get_by_id("cpd11416_c0ksp"): -0.63,
                          model2.metabolites.get_by_id("cpd11416_c0csp"): -0.37,
                          cpd11416_c0: 1
                         })

        
reaction.reaction
model.add_reactions([reaction])
print(count)

reaction = Reaction('EX_cpd11416_c0')
reaction.name = ('EX_cpd11416_c0')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({
                          model.metabolites.get_by_id("cpd11416_c0"): -1,
                          cpd11416_b: 1
                        })

        
reaction.reaction
model.add_reactions([reaction])

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

model.objective = 'Bio1'

model.reactions.EX_cpd00009_e0.bounds=(-.14,.14)
print('Community model has been reconstructed')

print('Model objective Bio1: ', model.slim_optimize())
cobra.io.write_sbml_model(model,'Output_GCM/GCM_P2_P3.xml')

F = model.optimize()
flux_p2_p3=F.fluxes
flux_p2_p3.to_csv("Output_FBA/FBA_p2_p3.csv")
# Out:
# 1757
# 1824
# 1996
# 1260
# 1329
# 1242
# 1561
# 1181
# 1
# 1
# 3
# 2
# Ignoring reaction 'EX_cpd11416_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_b' since it already exists.
# Ignoring reaction 'EX_cpd00276_b' since it already exists.
# Ignoring reaction 'EX_cpd00001_b' since it already exists.
# Ignoring reaction 'EX_cpd00023_b' since it already exists.
# Ignoring reaction 'EX_cpd00058_b' since it already exists.
# Ignoring reaction 'EX_cpd00051_b' since it already exists.
# Ignoring reaction 'EX_cpd00100_b' since it already exists.
# Ignoring reaction 'EX_cpd00034_b' since it already exists.
# Ignoring reaction 'EX_cpd10516_b' since it already exists.
# Ignoring reaction 'EX_cpd00027_b' since it already exists.
# Ignoring reaction 'EX_cpd00322_b' since it already exists.
# Ignoring reaction 'EX_cpd00122_b' since it already exists.
# Ignoring reaction 'EX_cpd00254_b' since it already exists.
# Ignoring reaction 'EX_cpd00205_b' since it already exists.
# Ignoring reaction 'EX_cpd00048_b' since it already exists.
# Ignoring reaction 'EX_cpd00030_b' since it already exists.
# Ignoring reaction 'EX_cpd00149_b' since it already exists.
# Ignoring reaction 'EX_cpd00226_b' since it already exists.
# Ignoring reaction 'EX_cpd00007_b' since it already exists.
# Ignoring reaction 'EX_cpd00011_b' since it already exists.
# Ignoring reaction 'EX_cpd00063_b' since it already exists.
# Ignoring reaction 'EX_cpd00009_b' since it already exists.
# Ignoring reaction 'EX_cpd00099_b' since it already exists.
# 1756
# Ignoring reaction 'EX_cpd00067_e0' since it already exists.
# Ignoring reaction 'EX_cpd04097_e0' since it already exists.
# Ignoring reaction 'EX_cpd01030_e0' since it already exists.
# Ignoring reaction 'EX_cpd01012_e0' since it already exists.
# Ignoring reaction 'EX_cpd00208_e0' since it already exists.
# Ignoring reaction 'EX_cpd00276_e0' since it already exists.
# Ignoring reaction 'EX_cpd00082_e0' since it already exists.
# Ignoring reaction 'EX_cpd00001_e0' since it already exists.
# Ignoring reaction 'EX_cpd00023_e0' since it already exists.
# Ignoring reaction 'EX_cpd00971_e0' since it already exists.
# Ignoring reaction 'EX_cpd00058_e0' since it already exists.
# Ignoring reaction 'EX_cpd00314_e0' since it already exists.
# Ignoring reaction 'EX_cpd00013_e0' since it already exists.
# Ignoring reaction 'EX_cpd00051_e0' since it already exists.
# Ignoring reaction 'EX_cpd00064_e0' since it already exists.
# Ignoring reaction 'EX_cpd00179_e0' since it already exists.
# Ignoring reaction 'EX_cpd00100_e0' since it already exists.
# Ignoring reaction 'EX_cpd00034_e0' since it already exists.
# Ignoring reaction 'EX_cpd10516_e0' since it already exists.
# Ignoring reaction 'EX_cpd00027_e0' since it already exists.
# Ignoring reaction 'EX_cpd00076_e0' since it already exists.
# Ignoring reaction 'EX_cpd00322_e0' since it already exists.
# Ignoring reaction 'EX_cpd01171_e0' since it already exists.
# Ignoring reaction 'EX_cpd00122_e0' since it already exists.
# Ignoring reaction 'EX_cpd03696_e0' since it already exists.
# Ignoring reaction 'EX_cpd00588_e0' since it already exists.
# Ignoring reaction 'EX_cpd00254_e0' since it already exists.
# Ignoring reaction 'EX_cpd00205_e0' since it already exists.
# Ignoring reaction 'EX_cpd00138_e0' since it already exists.
# Ignoring reaction 'EX_cpd00048_e0' since it already exists.
# Ignoring reaction 'EX_cpd00030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00149_e0' since it already exists.
# Ignoring reaction 'EX_cpd00531_e0' since it already exists.
# Ignoring reaction 'EX_cpd00794_e0' since it already exists.
# Ignoring reaction 'EX_cpd00226_e0' since it already exists.
# Ignoring reaction 'EX_cpd00007_e0' since it already exists.
# Ignoring reaction 'EX_cpd00305_e0' since it already exists.
# Ignoring reaction 'EX_cpd00011_e0' since it already exists.
# Ignoring reaction 'EX_cpd00063_e0' since it already exists.
# Ignoring reaction 'EX_cpd00009_e0' since it already exists.
# Ignoring reaction 'EX_cpd00099_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_b' since it already exists.
# 1259
# 2948
# 3064
# 1618
# 1259
# 2950
# 3065
# 1618

# %% [markdown]
# Reconstruction of pairwise community model- GCM_P2_P4

# %%
##7Reconstruction of pairwise community model- GCM_P2_P4##


model1 = cobra.io.read_sbml_model(r'Final_GEM/ksp_P2.xml')
model2 = cobra.io.read_sbml_model(r'Final_GEM/osp_P4.xml')

print(len(model1.reactions))
print(len(model1.metabolites))
print(len(model1.genes))

#optimising the value#
solution=model1.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model1)

print(len(model2.reactions))
print(len(model2.metabolites))
print(len(model2.genes))

#optimising the value#
solution=model2.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model2)####use Jupyter notebook##


for i in model1.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"ksp"
        i.id=j
        i.compartment="c0ksp"

for i in model2.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"osp"
        i.id=j
        i.compartment="c0osp"

count=0
for i in model1.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"ksp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"osp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"ksp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"osp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"ksp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"osp"
        i.id=j
        count=count+1
print(count)

from cobra import Model, Reaction, Metabolite
model = Model('community_model6')
count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model1.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model2.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

from cobra import Metabolite
cpd11416_c0 = Metabolite(
    'cpd11416_c0',
    name='Complete_Biomass',
    compartment='c0'

    )

from cobra import Metabolite
cpd11416_b = Metabolite(
    'cpd11416_b',
    name='Complete_Biomass',
    compartment='e0'
    )

reaction = Reaction('Bio1')
reaction.name = ('Community_biomass')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({model1.metabolites.get_by_id("cpd11416_c0ksp"): -0.765,
                          model2.metabolites.get_by_id("cpd11416_c0osp"): -0.235,
                          cpd11416_c0: 1
                         })

        
reaction.reaction
model.add_reactions([reaction])
print(count)

reaction = Reaction('EX_cpd11416_c0')
reaction.name = ('EX_cpd11416_c0')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({
                          model.metabolites.get_by_id("cpd11416_c0"): -1,
                          cpd11416_b: 1
                        })

        
reaction.reaction
model.add_reactions([reaction])

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

model.objective = 'Bio1'

print('Community model has been reconstructed')
print('Model objective Bio1: ', model.slim_optimize())

cobra.io.write_sbml_model(model,'Output_GCM/GCM_P2_P4.xml')

F = model.optimize()
flux_p2_p4=F.fluxes
flux_p2_p4.to_csv("Output_FBA/FBA_p2_p4.csv")
# Out:
# 1757
# 1824
# 1996
# 1559
# 1594
# 2446
# 1561
# 1361
# 1
# 1
# 3
# 3
# Ignoring reaction 'EX_cpd11416_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_b' since it already exists.
# Ignoring reaction 'EX_cpd00129_b' since it already exists.
# Ignoring reaction 'EX_cpd00276_b' since it already exists.
# Ignoring reaction 'EX_cpd00001_b' since it already exists.
# Ignoring reaction 'EX_cpd00023_b' since it already exists.
# Ignoring reaction 'EX_cpd00367_b' since it already exists.
# Ignoring reaction 'EX_cpd00058_b' since it already exists.
# Ignoring reaction 'EX_cpd00184_b' since it already exists.
# Ignoring reaction 'EX_cpd00314_b' since it already exists.
# Ignoring reaction 'EX_cpd00222_b' since it already exists.
# Ignoring reaction 'EX_cpd00051_b' since it already exists.
# Ignoring reaction 'EX_cpd00100_b' since it already exists.
# Ignoring reaction 'EX_cpd00009_b' since it already exists.
# Ignoring reaction 'EX_cpd00034_b' since it already exists.
# Ignoring reaction 'EX_cpd00249_b' since it already exists.
# Ignoring reaction 'EX_cpd00264_b' since it already exists.
# Ignoring reaction 'EX_cpd00644_b' since it already exists.
# Ignoring reaction 'EX_cpd00122_b' since it already exists.
# Ignoring reaction 'EX_cpd00277_b' since it already exists.
# Ignoring reaction 'EX_cpd00118_b' since it already exists.
# Ignoring reaction 'EX_cpd00254_b' since it already exists.
# Ignoring reaction 'EX_cpd00065_b' since it already exists.
# Ignoring reaction 'EX_cpd10516_b' since it already exists.
# Ignoring reaction 'EX_cpd00149_b' since it already exists.
# Ignoring reaction 'EX_cpd00027_b' since it already exists.
# Ignoring reaction 'EX_cpd00794_b' since it already exists.
# Ignoring reaction 'EX_cpd00226_b' since it already exists.
# Ignoring reaction 'EX_cpd00048_b' since it already exists.
# Ignoring reaction 'EX_cpd00322_b' since it already exists.
# Ignoring reaction 'EX_cpd00007_b' since it already exists.
# Ignoring reaction 'EX_cpd00092_b' since it already exists.
# Ignoring reaction 'EX_cpd00039_b' since it already exists.
# Ignoring reaction 'EX_cpd00011_b' since it already exists.
# Ignoring reaction 'EX_cpd00030_b' since it already exists.
# Ignoring reaction 'EX_cpd00205_b' since it already exists.
# Ignoring reaction 'EX_cpd00099_b' since it already exists.
# Ignoring reaction 'EX_cpd00063_b' since it already exists.
# 1756
# Ignoring reaction 'EX_cpd00067_e0' since it already exists.
# Ignoring reaction 'EX_cpd00182_e0' since it already exists.
# Ignoring reaction 'EX_cpd11576_e0' since it already exists.
# Ignoring reaction 'EX_cpd04097_e0' since it already exists.
# Ignoring reaction 'EX_cpd11585_e0' since it already exists.
# Ignoring reaction 'EX_cpd00412_e0' since it already exists.
# Ignoring reaction 'EX_cpd11582_e0' since it already exists.
# Ignoring reaction 'EX_cpd11586_e0' since it already exists.
# Ignoring reaction 'EX_cpd01030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00129_e0' since it already exists.
# Ignoring reaction 'EX_cpd00971_e0' since it already exists.
# Ignoring reaction 'EX_cpd01012_e0' since it already exists.
# Ignoring reaction 'EX_cpd00246_e0' since it already exists.
# Ignoring reaction 'EX_cpd00276_e0' since it already exists.
# Ignoring reaction 'EX_cpd00082_e0' since it already exists.
# Ignoring reaction 'EX_cpd00080_e0' since it already exists.
# Ignoring reaction 'EX_cpd00001_e0' since it already exists.
# Ignoring reaction 'EX_cpd00023_e0' since it already exists.
# Ignoring reaction 'EX_cpd15560_e0' since it already exists.
# Ignoring reaction 'EX_cpd15561_e0' since it already exists.
# Ignoring reaction 'EX_cpd00367_e0' since it already exists.
# Ignoring reaction 'EX_cpd00058_e0' since it already exists.
# Ignoring reaction 'EX_cpd00184_e0' since it already exists.
# Ignoring reaction 'EX_cpd00314_e0' since it already exists.
# Ignoring reaction 'EX_cpd01017_e0' since it already exists.
# Ignoring reaction 'EX_cpd00222_e0' since it already exists.
# Ignoring reaction 'EX_cpd00051_e0' since it already exists.
# Ignoring reaction 'EX_cpd00064_e0' since it already exists.
# Ignoring reaction 'EX_cpd11578_e0' since it already exists.
# Ignoring reaction 'EX_cpd00179_e0' since it already exists.
# Ignoring reaction 'EX_cpd00100_e0' since it already exists.
# Ignoring reaction 'EX_cpd11591_e0' since it already exists.
# Ignoring reaction 'EX_cpd00009_e0' since it already exists.
# Ignoring reaction 'EX_cpd00060_e0' since it already exists.
# Ignoring reaction 'EX_cpd00438_e0' since it already exists.
# Ignoring reaction 'EX_cpd00034_e0' since it already exists.
# Ignoring reaction 'EX_cpd00249_e0' since it already exists.
# Ignoring reaction 'EX_cpd11593_e0' since it already exists.
# Ignoring reaction 'EX_cpd00654_e0' since it already exists.
# Ignoring reaction 'EX_cpd00076_e0' since it already exists.
# Ignoring reaction 'EX_cpd03198_e0' since it already exists.
# Ignoring reaction 'EX_cpd11579_e0' since it already exists.
# Ignoring reaction 'EX_cpd01171_e0' since it already exists.
# Ignoring reaction 'EX_cpd00210_e0' since it already exists.
# Ignoring reaction 'EX_cpd00176_e0' since it already exists.
# Ignoring reaction 'EX_cpd15605_e0' since it already exists.
# Ignoring reaction 'EX_cpd00264_e0' since it already exists.
# Ignoring reaction 'EX_cpd00644_e0' since it already exists.
# Ignoring reaction 'EX_cpd00154_e0' since it already exists.
# Ignoring reaction 'EX_cpd03724_e0' since it already exists.
# Ignoring reaction 'EX_cpd00637_e0' since it already exists.
# Ignoring reaction 'EX_cpd00122_e0' since it already exists.
# Ignoring reaction 'EX_cpd15603_e0' since it already exists.
# Ignoring reaction 'EX_cpd03696_e0' since it already exists.
# Ignoring reaction 'EX_cpd00277_e0' since it already exists.
# Ignoring reaction 'EX_cpd00118_e0' since it already exists.
# Ignoring reaction 'EX_cpd00309_e0' since it already exists.
# Ignoring reaction 'EX_cpd11580_e0' since it already exists.
# Ignoring reaction 'EX_cpd01092_e0' since it already exists.
# Ignoring reaction 'EX_cpd03279_e0' since it already exists.
# Ignoring reaction 'EX_cpd00588_e0' since it already exists.
# Ignoring reaction 'EX_cpd00108_e0' since it already exists.
# Ignoring reaction 'EX_cpd00307_e0' since it already exists.
# Ignoring reaction 'EX_cpd00653_e0' since it already exists.
# Ignoring reaction 'EX_cpd00254_e0' since it already exists.
# Ignoring reaction 'EX_cpd00138_e0' since it already exists.
# Ignoring reaction 'EX_cpd00305_e0' since it already exists.
# Ignoring reaction 'EX_cpd03048_e0' since it already exists.
# Ignoring reaction 'EX_cpd11596_e0' since it already exists.
# Ignoring reaction 'EX_cpd00065_e0' since it already exists.
# Ignoring reaction 'EX_cpd15606_e0' since it already exists.
# Ignoring reaction 'EX_cpd10516_e0' since it already exists.
# Ignoring reaction 'EX_cpd00149_e0' since it already exists.
# Ignoring reaction 'EX_cpd01914_e0' since it already exists.
# Ignoring reaction 'EX_cpd00531_e0' since it already exists.
# Ignoring reaction 'EX_cpd11583_e0' since it already exists.
# Ignoring reaction 'EX_cpd00395_e0' since it already exists.
# Ignoring reaction 'EX_cpd11589_e0' since it already exists.
# Ignoring reaction 'EX_cpd00027_e0' since it already exists.
# Ignoring reaction 'EX_cpd11575_e0' since it already exists.
# Ignoring reaction 'EX_cpd00794_e0' since it already exists.
# Ignoring reaction 'EX_cpd00226_e0' since it already exists.
# Ignoring reaction 'EX_cpd09878_e0' since it already exists.
# Ignoring reaction 'EX_cpd11588_e0' since it already exists.
# Ignoring reaction 'EX_cpd00048_e0' since it already exists.
# Ignoring reaction 'EX_cpd15604_e0' since it already exists.
# Ignoring reaction 'EX_cpd00322_e0' since it already exists.
# Ignoring reaction 'EX_cpd00007_e0' since it already exists.
# Ignoring reaction 'EX_cpd11592_e0' since it already exists.
# Ignoring reaction 'EX_cpd08023_e0' since it already exists.
# Ignoring reaction 'EX_cpd11587_e0' since it already exists.
# Ignoring reaction 'EX_cpd00092_e0' since it already exists.
# Ignoring reaction 'EX_cpd11590_e0' since it already exists.
# Ignoring reaction 'EX_cpd11581_e0' since it already exists.
# Ignoring reaction 'EX_cpd11584_e0' since it already exists.
# Ignoring reaction 'EX_cpd00158_e0' since it already exists.
# Ignoring reaction 'EX_cpd00039_e0' since it already exists.
# Ignoring reaction 'EX_cpd00011_e0' since it already exists.
# Ignoring reaction 'EX_cpd00030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00013_e0' since it already exists.
# Ignoring reaction 'EX_cpd00205_e0' since it already exists.
# Ignoring reaction 'EX_cpd00099_e0' since it already exists.
# Ignoring reaction 'EX_cpd00063_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_b' since it already exists.
# 1558
# 3171
# 3205
# 2220
# 1558
# 3173
# 3206
# 2220

# %% [markdown]
# Reconstruction of pairwise community model- GCM_P2_P5

# %%
##8Reconstruction of pairwise community model- GCM_P2_P5##

import cobra
import sys
import os

model1 = cobra.io.read_sbml_model(r'Final_GEM/ksp_P2.xml')
model2 = cobra.io.read_sbml_model(r'Final_GEM/bsp_P5.xml')

print(len(model1.reactions))
print(len(model1.metabolites))
print(len(model1.genes))

#optimising the value#
solution=model1.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model1)

print(len(model2.reactions))
print(len(model2.metabolites))
print(len(model2.genes))

#optimising the value#
solution=model2.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model2)####use Jupyter notebook##


for i in model1.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"ksp"
        i.id=j
        i.compartment="c0ksp"

for i in model2.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"bsp"
        i.id=j
        i.compartment="c0bsp"

count=0
for i in model1.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"ksp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"bsp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"ksp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"bsp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"ksp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"bsp"
        i.id=j
        count=count+1
print(count)

from cobra import Model, Reaction, Metabolite
model = Model('community_model10')
count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model1.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model2.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

from cobra import Metabolite
cpd11416_c0 = Metabolite(
    'cpd11416_c0',
    name='Complete_Biomass',
    compartment='c0'

    )

from cobra import Metabolite
cpd11416_b = Metabolite(
    'cpd11416_b',
    name='Complete_Biomass',
    compartment='e0'
    )

reaction = Reaction('Bio1')
reaction.name = ('Community_biomass')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({model1.metabolites.get_by_id("cpd11416_c0ksp"): -0.42,
                          model2.metabolites.get_by_id("cpd11416_c0bsp"): -0.58,
                          cpd11416_c0: 1
                         })

        
reaction.reaction
model.add_reactions([reaction])
print(count)

reaction = Reaction('EX_cpd11416_c0')
reaction.name = ('EX_cpd11416_c0')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({
                          model.metabolites.get_by_id("cpd11416_c0"): -1,
                          cpd11416_b: 1
                        })

        
reaction.reaction
model.add_reactions([reaction])

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

model.objective = 'Bio1'

print('Community model has been reconstructed')
print('Model objective Bio1: ', model.slim_optimize())

cobra.io.write_sbml_model(model,'Output_GCM/GCM_P2_P5.xml')

F = model.optimize()
flux_p2_p5=F.fluxes
flux_p2_p5.to_csv("Output_FBA/FBA_p2_p5.csv")
# Out:
# 1757
# 1824
# 1996
# 1489
# 1500
# 1562
# 1561
# 1312
# 1
# 1
# 3
# 1
# Ignoring reaction 'EX_cpd11416_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_b' since it already exists.
# Ignoring reaction 'EX_cpd00276_b' since it already exists.
# Ignoring reaction 'EX_cpd00001_b' since it already exists.
# Ignoring reaction 'EX_cpd00023_b' since it already exists.
# Ignoring reaction 'EX_cpd00058_b' since it already exists.
# Ignoring reaction 'EX_cpd00314_b' since it already exists.
# Ignoring reaction 'EX_cpd00051_b' since it already exists.
# Ignoring reaction 'EX_cpd00100_b' since it already exists.
# Ignoring reaction 'EX_cpd00060_b' since it already exists.
# Ignoring reaction 'EX_cpd00034_b' since it already exists.
# Ignoring reaction 'EX_cpd10516_b' since it already exists.
# Ignoring reaction 'EX_cpd00264_b' since it already exists.
# Ignoring reaction 'EX_cpd00122_b' since it already exists.
# Ignoring reaction 'EX_cpd00035_b' since it already exists.
# Ignoring reaction 'EX_cpd00118_b' since it already exists.
# Ignoring reaction 'EX_cpd00254_b' since it already exists.
# Ignoring reaction 'EX_cpd00205_b' since it already exists.
# Ignoring reaction 'EX_cpd00039_b' since it already exists.
# Ignoring reaction 'EX_cpd00009_b' since it already exists.
# Ignoring reaction 'EX_cpd00048_b' since it already exists.
# Ignoring reaction 'EX_cpd00030_b' since it already exists.
# Ignoring reaction 'EX_cpd00149_b' since it already exists.
# Ignoring reaction 'EX_cpd00027_b' since it already exists.
# Ignoring reaction 'EX_cpd00794_b' since it already exists.
# Ignoring reaction 'EX_cpd00226_b' since it already exists.
# Ignoring reaction 'EX_cpd00268_b' since it already exists.
# Ignoring reaction 'EX_cpd00007_b' since it already exists.
# Ignoring reaction 'EX_cpd00092_b' since it already exists.
# Ignoring reaction 'EX_cpd00011_b' since it already exists.
# Ignoring reaction 'EX_cpd00063_b' since it already exists.
# Ignoring reaction 'EX_cpd00099_b' since it already exists.
# 1756
# Ignoring reaction 'EX_cpd00067_e0' since it already exists.
# Ignoring reaction 'EX_cpd00106_e0' since it already exists.
# Ignoring reaction 'EX_cpd00036_e0' since it already exists.
# Ignoring reaction 'EX_cpd11576_e0' since it already exists.
# Ignoring reaction 'EX_cpd04097_e0' since it already exists.
# Ignoring reaction 'EX_cpd11585_e0' since it already exists.
# Ignoring reaction 'EX_cpd11582_e0' since it already exists.
# Ignoring reaction 'EX_cpd00012_e0' since it already exists.
# Ignoring reaction 'EX_cpd11586_e0' since it already exists.
# Ignoring reaction 'EX_cpd01030_e0' since it already exists.
# Ignoring reaction 'EX_cpd01012_e0' since it already exists.
# Ignoring reaction 'EX_cpd00635_e0' since it already exists.
# Ignoring reaction 'EX_cpd00276_e0' since it already exists.
# Ignoring reaction 'EX_cpd00082_e0' since it already exists.
# Ignoring reaction 'EX_cpd00001_e0' since it already exists.
# Ignoring reaction 'EX_cpd00023_e0' since it already exists.
# Ignoring reaction 'EX_cpd00971_e0' since it already exists.
# Ignoring reaction 'EX_cpd00058_e0' since it already exists.
# Ignoring reaction 'EX_cpd00314_e0' since it already exists.
# Ignoring reaction 'EX_cpd01017_e0' since it already exists.
# Ignoring reaction 'EX_cpd00051_e0' since it already exists.
# Ignoring reaction 'EX_cpd00064_e0' since it already exists.
# Ignoring reaction 'EX_cpd00179_e0' since it already exists.
# Ignoring reaction 'EX_cpd00100_e0' since it already exists.
# Ignoring reaction 'EX_cpd11591_e0' since it already exists.
# Ignoring reaction 'EX_cpd00060_e0' since it already exists.
# Ignoring reaction 'EX_cpd00034_e0' since it already exists.
# Ignoring reaction 'EX_cpd10516_e0' since it already exists.
# Ignoring reaction 'EX_cpd11593_e0' since it already exists.
# Ignoring reaction 'EX_cpd00076_e0' since it already exists.
# Ignoring reaction 'EX_cpd01171_e0' since it already exists.
# Ignoring reaction 'EX_cpd15605_e0' since it already exists.
# Ignoring reaction 'EX_cpd00264_e0' since it already exists.
# Ignoring reaction 'EX_cpd03724_e0' since it already exists.
# Ignoring reaction 'EX_cpd00637_e0' since it already exists.
# Ignoring reaction 'EX_cpd00122_e0' since it already exists.
# Ignoring reaction 'EX_cpd00035_e0' since it already exists.
# Ignoring reaction 'EX_cpd15603_e0' since it already exists.
# Ignoring reaction 'EX_cpd03696_e0' since it already exists.
# Ignoring reaction 'EX_cpd00118_e0' since it already exists.
# Ignoring reaction 'EX_cpd00309_e0' since it already exists.
# Ignoring reaction 'EX_cpd11580_e0' since it already exists.
# Ignoring reaction 'EX_cpd00137_e0' since it already exists.
# Ignoring reaction 'EX_cpd00588_e0' since it already exists.
# Ignoring reaction 'EX_cpd00117_e0' since it already exists.
# Ignoring reaction 'EX_cpd00254_e0' since it already exists.
# Ignoring reaction 'EX_cpd00205_e0' since it already exists.
# Ignoring reaction 'EX_cpd00138_e0' since it already exists.
# Ignoring reaction 'EX_cpd00039_e0' since it already exists.
# Ignoring reaction 'EX_cpd00009_e0' since it already exists.
# Ignoring reaction 'EX_cpd15606_e0' since it already exists.
# Ignoring reaction 'EX_cpd00048_e0' since it already exists.
# Ignoring reaction 'EX_cpd00030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00149_e0' since it already exists.
# Ignoring reaction 'EX_cpd01914_e0' since it already exists.
# Ignoring reaction 'EX_cpd00531_e0' since it already exists.
# Ignoring reaction 'EX_cpd11583_e0' since it already exists.
# Ignoring reaction 'EX_cpd11589_e0' since it already exists.
# Ignoring reaction 'EX_cpd00027_e0' since it already exists.
# Ignoring reaction 'EX_cpd00794_e0' since it already exists.
# Ignoring reaction 'EX_cpd00226_e0' since it already exists.
# Ignoring reaction 'EX_cpd11588_e0' since it already exists.
# Ignoring reaction 'EX_cpd00268_e0' since it already exists.
# Ignoring reaction 'EX_cpd15604_e0' since it already exists.
# Ignoring reaction 'EX_cpd00007_e0' since it already exists.
# Ignoring reaction 'EX_cpd11592_e0' since it already exists.
# Ignoring reaction 'EX_cpd11587_e0' since it already exists.
# Ignoring reaction 'EX_cpd00092_e0' since it already exists.
# Ignoring reaction 'EX_cpd00053_e0' since it already exists.
# Ignoring reaction 'EX_cpd11590_e0' since it already exists.
# Ignoring reaction 'EX_cpd11581_e0' since it already exists.
# Ignoring reaction 'EX_cpd11584_e0' since it already exists.
# Ignoring reaction 'EX_cpd00158_e0' since it already exists.
# Ignoring reaction 'EX_cpd00011_e0' since it already exists.
# Ignoring reaction 'EX_cpd00063_e0' since it already exists.
# Ignoring reaction 'EX_cpd00013_e0' since it already exists.
# Ignoring reaction 'EX_cpd00099_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_b' since it already exists.
# 1488
# 3133
# 3165
# 1778
# 1488
# 3135
# 3166
# 1778

# %% [markdown]
# Reconstruction of pairwise community model- GCM_P2_P6

# %%
##9Reconstruction of pairwise community model- GCM_P2_P6##

import cobra
import sys
import os

model1 = cobra.io.read_sbml_model(r'Final_GEM/ksp_P2.xml')
model2 = cobra.io.read_sbml_model(r'Final_GEM/nc_P6.xml')

print(len(model1.reactions))
print(len(model1.metabolites))
print(len(model1.genes))

#optimising the value#
solution=model1.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model1)

print(len(model2.reactions))
print(len(model2.metabolites))
print(len(model2.genes))

#optimising the value#
solution=model2.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model2)####use Jupyter notebook##


for i in model1.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"ksp"
        i.id=j
        i.compartment="c0ksp"

for i in model2.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"nc"
        i.id=j
        i.compartment="c0nc"

count=0
for i in model1.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"ksp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"nc"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"ksp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"nc"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"ksp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"nc"
        i.id=j
        count=count+1
print(count)

from cobra import Model, Reaction, Metabolite
model = Model('community_model4')
count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model1.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model2.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

from cobra import Metabolite
cpd11416_c0 = Metabolite(
    'cpd11416_c0',
    name='Complete_Biomass',
    compartment='c0'

    )

from cobra import Metabolite
cpd11416_b = Metabolite(
    'cpd11416_b',
    name='Complete_Biomass',
    compartment='e0'
    )

reaction = Reaction('Bio1')
reaction.name = ('Community_biomass')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({model1.metabolites.get_by_id("cpd11416_c0ksp"): -0.59,
                          model2.metabolites.get_by_id("cpd11416_c0nc"): -0.41,
                          cpd11416_c0: 1
                         })

        
reaction.reaction
model.add_reactions([reaction])
print(count)

reaction = Reaction('EX_cpd11416_c0')
reaction.name = ('EX_cpd11416_c0')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({
                          model.metabolites.get_by_id("cpd11416_c0"): -1,
                          cpd11416_b: 1
                        })

        
reaction.reaction
model.add_reactions([reaction])

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

model.objective = 'Bio1'

print('Community model has been reconstructed')
print('Model objective Bio1: ', model.slim_optimize())

cobra.io.write_sbml_model(model,'Output_GCM/GCM_P2_P6.xml')

F = model.optimize()
flux_p2_p6=F.fluxes
flux_p2_p6.to_csv("Output_FBA/FBA_p2_p6.csv")
# Out:
# 1757
# 1824
# 1996
# 1577
# 1563
# 1942
# 1561
# 1366
# 1
# 1
# 3
# 2
# Ignoring reaction 'EX_cpd11416_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_b' since it already exists.
# Ignoring reaction 'EX_cpd00276_b' since it already exists.
# Ignoring reaction 'EX_cpd00001_b' since it already exists.
# Ignoring reaction 'EX_cpd00367_b' since it already exists.
# Ignoring reaction 'EX_cpd00058_b' since it already exists.
# Ignoring reaction 'EX_cpd00184_b' since it already exists.
# Ignoring reaction 'EX_cpd00314_b' since it already exists.
# Ignoring reaction 'EX_cpd00051_b' since it already exists.
# Ignoring reaction 'EX_cpd00100_b' since it already exists.
# Ignoring reaction 'EX_cpd00060_b' since it already exists.
# Ignoring reaction 'EX_cpd00438_b' since it already exists.
# Ignoring reaction 'EX_cpd00249_b' since it already exists.
# Ignoring reaction 'EX_cpd00264_b' since it already exists.
# Ignoring reaction 'EX_cpd00122_b' since it already exists.
# Ignoring reaction 'EX_cpd00035_b' since it already exists.
# Ignoring reaction 'EX_cpd00277_b' since it already exists.
# Ignoring reaction 'EX_cpd00118_b' since it already exists.
# Ignoring reaction 'EX_cpd00254_b' since it already exists.
# 1756
# Ignoring reaction 'EX_cpd00305_b' since it already exists.
# Ignoring reaction 'EX_cpd00009_b' since it already exists.
# Ignoring reaction 'EX_cpd10516_b' since it already exists.
# Ignoring reaction 'EX_cpd00030_b' since it already exists.
# Ignoring reaction 'EX_cpd00149_b' since it already exists.
# Ignoring reaction 'EX_cpd00027_b' since it already exists.
# Ignoring reaction 'EX_cpd00794_b' since it already exists.
# Ignoring reaction 'EX_cpd00226_b' since it already exists.
# Ignoring reaction 'EX_cpd00048_b' since it already exists.
# Ignoring reaction 'EX_cpd00007_b' since it already exists.
# Ignoring reaction 'EX_cpd00092_b' since it already exists.
# Ignoring reaction 'EX_cpd00205_b' since it already exists.
# Ignoring reaction 'EX_cpd00039_b' since it already exists.
# Ignoring reaction 'EX_cpd00011_b' since it already exists.
# Ignoring reaction 'EX_cpd00063_b' since it already exists.
# Ignoring reaction 'EX_cpd00034_b' since it already exists.
# Ignoring reaction 'EX_cpd00099_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_e0' since it already exists.
# Ignoring reaction 'EX_cpd00182_e0' since it already exists.
# Ignoring reaction 'EX_cpd11576_e0' since it already exists.
# Ignoring reaction 'EX_cpd04097_e0' since it already exists.
# Ignoring reaction 'EX_cpd11585_e0' since it already exists.
# Ignoring reaction 'EX_cpd00412_e0' since it already exists.
# Ignoring reaction 'EX_cpd11582_e0' since it already exists.
# Ignoring reaction 'EX_cpd00012_e0' since it already exists.
# Ignoring reaction 'EX_cpd11586_e0' since it already exists.
# Ignoring reaction 'EX_cpd01030_e0' since it already exists.
# Ignoring reaction 'EX_cpd01012_e0' since it already exists.
# Ignoring reaction 'EX_cpd00208_e0' since it already exists.
# Ignoring reaction 'EX_cpd00635_e0' since it already exists.
# Ignoring reaction 'EX_cpd00246_e0' since it already exists.
# Ignoring reaction 'EX_cpd00276_e0' since it already exists.
# Ignoring reaction 'EX_cpd00082_e0' since it already exists.
# Ignoring reaction 'EX_cpd00080_e0' since it already exists.
# Ignoring reaction 'EX_cpd00001_e0' since it already exists.
# Ignoring reaction 'EX_cpd00367_e0' since it already exists.
# Ignoring reaction 'EX_cpd00058_e0' since it already exists.
# Ignoring reaction 'EX_cpd00184_e0' since it already exists.
# Ignoring reaction 'EX_cpd00314_e0' since it already exists.
# Ignoring reaction 'EX_cpd01017_e0' since it already exists.
# Ignoring reaction 'EX_cpd00013_e0' since it already exists.
# Ignoring reaction 'EX_cpd00051_e0' since it already exists.
# Ignoring reaction 'EX_cpd00064_e0' since it already exists.
# Ignoring reaction 'EX_cpd00179_e0' since it already exists.
# Ignoring reaction 'EX_cpd00100_e0' since it already exists.
# Ignoring reaction 'EX_cpd11591_e0' since it already exists.
# Ignoring reaction 'EX_cpd00060_e0' since it already exists.
# Ignoring reaction 'EX_cpd00438_e0' since it already exists.
# Ignoring reaction 'EX_cpd00249_e0' since it already exists.
# Ignoring reaction 'EX_cpd11593_e0' since it already exists.
# Ignoring reaction 'EX_cpd00654_e0' since it already exists.
# Ignoring reaction 'EX_cpd00076_e0' since it already exists.
# Ignoring reaction 'EX_cpd03198_e0' since it already exists.
# Ignoring reaction 'EX_cpd01171_e0' since it already exists.
# Ignoring reaction 'EX_cpd00176_e0' since it already exists.
# Ignoring reaction 'EX_cpd15605_e0' since it already exists.
# Ignoring reaction 'EX_cpd00264_e0' since it already exists.
# Ignoring reaction 'EX_cpd00154_e0' since it already exists.
# Ignoring reaction 'EX_cpd00637_e0' since it already exists.
# Ignoring reaction 'EX_cpd00122_e0' since it already exists.
# Ignoring reaction 'EX_cpd00035_e0' since it already exists.
# Ignoring reaction 'EX_cpd15603_e0' since it already exists.
# Ignoring reaction 'EX_cpd03696_e0' since it already exists.
# Ignoring reaction 'EX_cpd00277_e0' since it already exists.
# Ignoring reaction 'EX_cpd00118_e0' since it already exists.
# Ignoring reaction 'EX_cpd00309_e0' since it already exists.
# Ignoring reaction 'EX_cpd11580_e0' since it already exists.
# Ignoring reaction 'EX_cpd01092_e0' since it already exists.
# Ignoring reaction 'EX_cpd03343_e0' since it already exists.
# Ignoring reaction 'EX_cpd03279_e0' since it already exists.
# Ignoring reaction 'EX_cpd00588_e0' since it already exists.
# Ignoring reaction 'EX_cpd00117_e0' since it already exists.
# Ignoring reaction 'EX_cpd00307_e0' since it already exists.
# Ignoring reaction 'EX_cpd00653_e0' since it already exists.
# Ignoring reaction 'EX_cpd00254_e0' since it already exists.
# Ignoring reaction 'EX_cpd00138_e0' since it already exists.
# Ignoring reaction 'EX_cpd00305_e0' since it already exists.
# Ignoring reaction 'EX_cpd00159_e0' since it already exists.
# Ignoring reaction 'EX_cpd00009_e0' since it already exists.
# Ignoring reaction 'EX_cpd15606_e0' since it already exists.
# Ignoring reaction 'EX_cpd10516_e0' since it already exists.
# Ignoring reaction 'EX_cpd00971_e0' since it already exists.
# Ignoring reaction 'EX_cpd00030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00149_e0' since it already exists.
# Ignoring reaction 'EX_cpd01914_e0' since it already exists.
# Ignoring reaction 'EX_cpd00531_e0' since it already exists.
# Ignoring reaction 'EX_cpd11583_e0' since it already exists.
# Ignoring reaction 'EX_cpd11589_e0' since it already exists.
# Ignoring reaction 'EX_cpd00027_e0' since it already exists.
# Ignoring reaction 'EX_cpd00794_e0' since it already exists.
# Ignoring reaction 'EX_cpd00226_e0' since it already exists.
# Ignoring reaction 'EX_cpd11588_e0' since it already exists.
# Ignoring reaction 'EX_cpd00048_e0' since it already exists.
# Ignoring reaction 'EX_cpd15604_e0' since it already exists.
# Ignoring reaction 'EX_cpd00007_e0' since it already exists.
# Ignoring reaction 'EX_cpd11592_e0' since it already exists.
# Ignoring reaction 'EX_cpd11587_e0' since it already exists.
# Ignoring reaction 'EX_cpd00092_e0' since it already exists.
# Ignoring reaction 'EX_cpd11590_e0' since it already exists.
# Ignoring reaction 'EX_cpd11581_e0' since it already exists.
# Ignoring reaction 'EX_cpd00205_e0' since it already exists.
# Ignoring reaction 'EX_cpd11584_e0' since it already exists.
# Ignoring reaction 'EX_cpd00158_e0' since it already exists.
# Ignoring reaction 'EX_cpd00039_e0' since it already exists.
# Ignoring reaction 'EX_cpd00011_e0' since it already exists.
# Ignoring reaction 'EX_cpd00063_e0' since it already exists.
# Ignoring reaction 'EX_cpd00034_e0' since it already exists.
# Ignoring reaction 'EX_cpd00099_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_b' since it already exists.
# 1576
# 3203
# 3199
# 1968
# 1576
# 3205
# 3200
# 1968

# %% [markdown]
# Reconstruction of pairwise community model- GCM_P3_P4

# %%
##10Reconstruction of pairwise community model- GCM_P3_P4##

import cobra
import sys
import os

model1 = cobra.io.read_sbml_model(r'Final_GEM/csp_P3.xml')
model2 = cobra.io.read_sbml_model(r'Final_GEM/osp_P4.xml')


print(len(model1.reactions))
print(len(model1.metabolites))
print(len(model1.genes))

#optimising the value#
solution=model1.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model1)

print(len(model2.reactions))
print(len(model2.metabolites))
print(len(model2.genes))

#optimising the value#
solution=model2.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model2)####use Jupyter notebook##


for i in model1.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"csp"
        i.id=j
        i.compartment="c0csp"

for i in model2.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"osp"
        i.id=j
        i.compartment="c0osp"

count=0
for i in model1.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"csp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"osp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"csp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"osp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"csp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"osp"
        i.id=j
        count=count+1
print(count)

from cobra import Model, Reaction, Metabolite
model = Model('community_model4')
count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model1.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model2.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

from cobra import Metabolite
cpd11416_c0 = Metabolite(
    'cpd11416_c0',
    name='Complete_Biomass',
    compartment='c0'

    )

from cobra import Metabolite
cpd11416_b = Metabolite(
    'cpd11416_b',
    name='Complete_Biomass',
    compartment='e0'
    )

reaction = Reaction('Bio1')
reaction.name = ('Community_biomass')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({model1.metabolites.get_by_id("cpd11416_c0csp"): -0.66,
                          model2.metabolites.get_by_id("cpd11416_c0osp"): -0.34,
                          cpd11416_c0: 1
                         })

        
reaction.reaction
model.add_reactions([reaction])
print(count)

reaction = Reaction('EX_cpd11416_c0')
reaction.name = ('EX_cpd11416_c0')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({
                          model.metabolites.get_by_id("cpd11416_c0"): -1,
                          cpd11416_b: 1
                        })

        
reaction.reaction
model.add_reactions([reaction])

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))
model.reactions.EX_cpd00067_e0.bounds = (-.97,.97)

model.objective = 'Bio1'

print('Community model has been reconstructed')
print('Model objective Bio1: ', model.slim_optimize())

cobra.io.write_sbml_model(model,'Output_GCM/GCM_P3_P4.xml')

F = model.optimize()
flux_p3_p4=F.fluxes
flux_p3_p4.to_csv("Output_FBA/FBA_p3_p4.csv")
# Out:
# 1260
# 1329
# 1242
# 1559
# 1594
# 2446
# 1181
# 1361
# 1
# 1
# 2
# 3
# Ignoring reaction 'EX_cpd11416_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_b' since it already exists.
# Ignoring reaction 'EX_cpd00276_b' since it already exists.
# Ignoring reaction 'EX_cpd00082_b' since it already exists.
# Ignoring reaction 'EX_cpd00001_b' since it already exists.
# Ignoring reaction 'EX_cpd00023_b' since it already exists.
# Ignoring reaction 'EX_cpd00058_b' since it already exists.
# Ignoring reaction 'EX_cpd00051_b' since it already exists.
# Ignoring reaction 'EX_cpd00064_b' since it already exists.
# Ignoring reaction 'EX_cpd00100_b' since it already exists.
# Ignoring reaction 'EX_cpd00009_b' since it already exists.
# Ignoring reaction 'EX_cpd00034_b' since it already exists.
# Ignoring reaction 'EX_cpd00122_b' since it already exists.
# Ignoring reaction 'EX_cpd00254_b' since it already exists.
# Ignoring reaction 'EX_cpd10516_b' since it already exists.
# Ignoring reaction 'EX_cpd00149_b' since it already exists.
# Ignoring reaction 'EX_cpd00027_b' since it already exists.
# Ignoring reaction 'EX_cpd00226_b' since it already exists.
# Ignoring reaction 'EX_cpd00048_b' since it already exists.
# Ignoring reaction 'EX_cpd00322_b' since it already exists.
# Ignoring reaction 'EX_cpd00007_b' since it already exists.
# Ignoring reaction 'EX_cpd00011_b' since it already exists.
# Ignoring reaction 'EX_cpd00030_b' since it already exists.
# Ignoring reaction 'EX_cpd00013_b' since it already exists.
# Ignoring reaction 'EX_cpd00205_b' since it already exists.
# Ignoring reaction 'EX_cpd00099_b' since it already exists.
# Ignoring reaction 'EX_cpd00063_b' since it already exists.
# 1259
# Ignoring reaction 'EX_cpd00067_e0' since it already exists.
# Ignoring reaction 'EX_cpd04097_e0' since it already exists.
# Ignoring reaction 'EX_cpd01030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00971_e0' since it already exists.
# Ignoring reaction 'EX_cpd01012_e0' since it already exists.
# Ignoring reaction 'EX_cpd00276_e0' since it already exists.
# Ignoring reaction 'EX_cpd00082_e0' since it already exists.
# Ignoring reaction 'EX_cpd00001_e0' since it already exists.
# Ignoring reaction 'EX_cpd00023_e0' since it already exists.
# Ignoring reaction 'EX_cpd00058_e0' since it already exists.
# Ignoring reaction 'EX_cpd00107_e0' since it already exists.
# Ignoring reaction 'EX_cpd00314_e0' since it already exists.
# Ignoring reaction 'EX_cpd00051_e0' since it already exists.
# Ignoring reaction 'EX_cpd00064_e0' since it already exists.
# Ignoring reaction 'EX_cpd00179_e0' since it already exists.
# Ignoring reaction 'EX_cpd00100_e0' since it already exists.
# Ignoring reaction 'EX_cpd00009_e0' since it already exists.
# Ignoring reaction 'EX_cpd00034_e0' since it already exists.
# Ignoring reaction 'EX_cpd00076_e0' since it already exists.
# Ignoring reaction 'EX_cpd01171_e0' since it already exists.
# Ignoring reaction 'EX_cpd00122_e0' since it already exists.
# Ignoring reaction 'EX_cpd03696_e0' since it already exists.
# Ignoring reaction 'EX_cpd00588_e0' since it already exists.
# Ignoring reaction 'EX_cpd00254_e0' since it already exists.
# Ignoring reaction 'EX_cpd00138_e0' since it already exists.
# Ignoring reaction 'EX_cpd00305_e0' since it already exists.
# Ignoring reaction 'EX_cpd10516_e0' since it already exists.
# Ignoring reaction 'EX_cpd00149_e0' since it already exists.
# Ignoring reaction 'EX_cpd00531_e0' since it already exists.
# Ignoring reaction 'EX_cpd00027_e0' since it already exists.
# Ignoring reaction 'EX_cpd00794_e0' since it already exists.
# Ignoring reaction 'EX_cpd00226_e0' since it already exists.
# Ignoring reaction 'EX_cpd00048_e0' since it already exists.
# Ignoring reaction 'EX_cpd00322_e0' since it already exists.
# Ignoring reaction 'EX_cpd00104_e0' since it already exists.
# Ignoring reaction 'EX_cpd00007_e0' since it already exists.
# Ignoring reaction 'EX_cpd00156_e0' since it already exists.
# Ignoring reaction 'EX_cpd00011_e0' since it already exists.
# Ignoring reaction 'EX_cpd00030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00013_e0' since it already exists.
# Ignoring reaction 'EX_cpd00205_e0' since it already exists.
# Ignoring reaction 'EX_cpd00099_e0' since it already exists.
# Ignoring reaction 'EX_cpd00063_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_b' since it already exists.
# 1558
# 2745
# 2830
# 1843
# 1558
# 2747
# 2831
# 1843

# %% [markdown]
# Reconstruction of pairwise community model- GCM_P3_P5

# %%
##11Reconstruction of pairwise community model- GCM_P3_P5##

import cobra
import sys
import os

model1 = cobra.io.read_sbml_model(r'Final_GEM/bsp_P5.xml')
model2 = cobra.io.read_sbml_model(r'Final_GEM/csp_P3.xml')

print(len(model1.reactions))
print(len(model1.metabolites))
print(len(model1.genes))

#optimising the value#
solution=model1.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model1)

print(len(model2.reactions))
print(len(model2.metabolites))
print(len(model2.genes))

#optimising the value#
solution=model2.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model2)####use Jupyter notebook##

for i in model1.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"bsp"
        i.id=j
        i.compartment="c0bsp"

for i in model2.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"csp"
        i.id=j
        i.compartment="c0csp"

count=0
for i in model1.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"bsp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"csp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"bsp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"csp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"bsp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"csp"
        i.id=j
        count=count+1
print(count)

from cobra import Model, Reaction, Metabolite
model = Model('community_model1')
count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model1.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model2.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

from cobra import Metabolite
cpd11416_c0 = Metabolite(
    'cpd11416_c0',
    name='Complete_Biomass',
    compartment='c0'

    )

from cobra import Metabolite
cpd11416_b = Metabolite(
    'cpd11416_b',
    name='Complete_Biomass',
    compartment='e0'
    )

reaction = Reaction('Bio1')
reaction.name = ('Community_biomass')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({model1.metabolites.get_by_id("cpd11416_c0bsp"): -0.70,
                          model2.metabolites.get_by_id("cpd11416_c0csp"): -0.30,
                          cpd11416_c0: 1
                         })

        
reaction.reaction
model.add_reactions([reaction])
print(count)

reaction = Reaction('EX_cpd11416_c0')
reaction.name = ('EX_cpd11416_c0')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({
                          model.metabolites.get_by_id("cpd11416_c0"): -1,
                          cpd11416_b: 1
                        })

        
reaction.reaction
model.add_reactions([reaction])

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

model.objective = 'Bio1'

model.reactions.rxn05518_c0bsp.bounds = (-100,100)

print('Community model has been reconstructed')
print('Model objective Bio1: ', model.slim_optimize())

cobra.io.write_sbml_model(model,'Output_GCM/GCM_P3_P5.xml')

F = model.optimize()
flux_p3_p5=F.fluxes
flux_p3_p5.to_csv("Output_FBA/FBA_p3_p5.csv")
# Out:
# 1489
# 1500
# 1562
# 1260
# 1329
# 1242
# 1312
# 1181
# 1
# 1
# 1
# 2
# Ignoring reaction 'EX_cpd11416_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_b' since it already exists.
# Ignoring reaction 'EX_cpd00276_b' since it already exists.
# Ignoring reaction 'EX_cpd00082_b' since it already exists.
# Ignoring reaction 'EX_cpd00001_b' since it already exists.
# Ignoring reaction 'EX_cpd00023_b' since it already exists.
# Ignoring reaction 'EX_cpd00058_b' since it already exists.
# Ignoring reaction 'EX_cpd00013_b' since it already exists.
# Ignoring reaction 'EX_cpd00051_b' since it already exists.
# Ignoring reaction 'EX_cpd00064_b' since it already exists.
# Ignoring reaction 'EX_cpd00100_b' since it already exists.
# Ignoring reaction 'EX_cpd00034_b' since it already exists.
# Ignoring reaction 'EX_cpd10516_b' since it already exists.
# Ignoring reaction 'EX_cpd00027_b' since it already exists.
# Ignoring reaction 'EX_cpd00122_b' since it already exists.
# Ignoring reaction 'EX_cpd00254_b' since it already exists.
# Ignoring reaction 'EX_cpd00205_b' since it already exists.
# Ignoring reaction 'EX_cpd00048_b' since it already exists.
# Ignoring reaction 'EX_cpd00030_b' since it already exists.
# Ignoring reaction 'EX_cpd00149_b' since it already exists.
# Ignoring reaction 'EX_cpd00226_b' since it already exists.
# Ignoring reaction 'EX_cpd00007_b' since it already exists.
# Ignoring reaction 'EX_cpd00011_b' since it already exists.
# Ignoring reaction 'EX_cpd00063_b' since it already exists.
# Ignoring reaction 'EX_cpd00009_b' since it already exists.
# Ignoring reaction 'EX_cpd00099_b' since it already exists.
# 1488
# Ignoring reaction 'EX_cpd00067_e0' since it already exists.
# Ignoring reaction 'EX_cpd04097_e0' since it already exists.
# Ignoring reaction 'EX_cpd01030_e0' since it already exists.
# Ignoring reaction 'EX_cpd01012_e0' since it already exists.
# Ignoring reaction 'EX_cpd00276_e0' since it already exists.
# Ignoring reaction 'EX_cpd00082_e0' since it already exists.
# Ignoring reaction 'EX_cpd00001_e0' since it already exists.
# Ignoring reaction 'EX_cpd00023_e0' since it already exists.
# Ignoring reaction 'EX_cpd00971_e0' since it already exists.
# Ignoring reaction 'EX_cpd00058_e0' since it already exists.
# Ignoring reaction 'EX_cpd00314_e0' since it already exists.
# Ignoring reaction 'EX_cpd00013_e0' since it already exists.
# Ignoring reaction 'EX_cpd00051_e0' since it already exists.
# Ignoring reaction 'EX_cpd00064_e0' since it already exists.
# Ignoring reaction 'EX_cpd00179_e0' since it already exists.
# Ignoring reaction 'EX_cpd00100_e0' since it already exists.
# Ignoring reaction 'EX_cpd00034_e0' since it already exists.
# Ignoring reaction 'EX_cpd10516_e0' since it already exists.
# Ignoring reaction 'EX_cpd00027_e0' since it already exists.
# Ignoring reaction 'EX_cpd00076_e0' since it already exists.
# Ignoring reaction 'EX_cpd01171_e0' since it already exists.
# Ignoring reaction 'EX_cpd00122_e0' since it already exists.
# Ignoring reaction 'EX_cpd03696_e0' since it already exists.
# Ignoring reaction 'EX_cpd00588_e0' since it already exists.
# Ignoring reaction 'EX_cpd00254_e0' since it already exists.
# Ignoring reaction 'EX_cpd00205_e0' since it already exists.
# Ignoring reaction 'EX_cpd00138_e0' since it already exists.
# Ignoring reaction 'EX_cpd00048_e0' since it already exists.
# Ignoring reaction 'EX_cpd00030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00149_e0' since it already exists.
# Ignoring reaction 'EX_cpd00531_e0' since it already exists.
# Ignoring reaction 'EX_cpd00794_e0' since it already exists.
# Ignoring reaction 'EX_cpd00226_e0' since it already exists.
# Ignoring reaction 'EX_cpd00104_e0' since it already exists.
# Ignoring reaction 'EX_cpd00007_e0' since it already exists.
# Ignoring reaction 'EX_cpd00011_e0' since it already exists.
# Ignoring reaction 'EX_cpd00063_e0' since it already exists.
# Ignoring reaction 'EX_cpd00009_e0' since it already exists.
# Ignoring reaction 'EX_cpd00099_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_b' since it already exists.
# 1259
# 2680
# 2746
# 1401
# 1259
# 2682
# 2747
# 1401

# %% [markdown]
# Reconstruction of pairwise community model- GCM_P3_P6

# %%
##12Reconstruction of pairwise community model- GCM_P3_P6##

import cobra
import sys
import os

model1 = cobra.io.read_sbml_model(r'Final_GEM/nc_P6.xml')
model2 = cobra.io.read_sbml_model(r'Final_GEM/csp_P3.xml')

print(len(model1.reactions))
print(len(model1.metabolites))
print(len(model1.genes))

#optimising the value#
solution=model1.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model1)

print(len(model2.reactions))
print(len(model2.metabolites))
print(len(model2.genes))

#optimising the value#
solution=model2.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model2)####use Jupyter notebook##


for i in model2.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"csp"
        i.id=j
        i.compartment="c0csp"

for i in model1.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"nc"
        i.id=j
        i.compartment="c0nc"

count=0
for i in model2.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"csp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"nc"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"csp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"nc"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"csp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"nc"
        i.id=j
        count=count+1
print(count)

from cobra import Model, Reaction, Metabolite
model = Model('community_model4')
count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model1.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model2.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

from cobra import Metabolite
cpd11416_c0 = Metabolite(
    'cpd11416_c0',
    name='Complete_Biomass',
    compartment='c0'

    )

from cobra import Metabolite
cpd11416_b = Metabolite(
    'cpd11416_b',
    name='Complete_Biomass',
    compartment='e0'
    )

reaction = Reaction('Bio1')
reaction.name = ('Community_biomass')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({model2.metabolites.get_by_id("cpd11416_c0csp"): -0.43,
                          model1.metabolites.get_by_id("cpd11416_c0nc"): -0.57,
                          cpd11416_c0: 1
                         })

        
reaction.reaction
model.add_reactions([reaction])
print(count)

reaction = Reaction('EX_cpd11416_c0')
reaction.name = ('EX_cpd11416_c0')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({
                          model.metabolites.get_by_id("cpd11416_c0"): -1,
                          cpd11416_b: 1
                        })

        
reaction.reaction
model.add_reactions([reaction])

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))
model.reactions.rxn05313_c0nc.bounds=(-.18,.18)

model.objective = 'Bio1'
print('Community model has been reconstructed')
print('Model objective Bio1: ', model.slim_optimize())


cobra.io.write_sbml_model(model,'Output_GCM/GCM_P3_P6.xml')

F = model.optimize()
flux_p3_p6=F.fluxes
flux_p3_p6.to_csv("Output_FBA/FBA_p3_p6.csv")
# Out:
# 1577
# 1563
# 1942
# 1260
# 1329
# 1242
# 1181
# 1366
# 1
# 1
# 2
# 2
# Ignoring reaction 'EX_cpd11416_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_b' since it already exists.
# Ignoring reaction 'EX_cpd00276_b' since it already exists.
# Ignoring reaction 'EX_cpd00082_b' since it already exists.
# Ignoring reaction 'EX_cpd00001_b' since it already exists.
# Ignoring reaction 'EX_cpd00058_b' since it already exists.
# Ignoring reaction 'EX_cpd00013_b' since it already exists.
# Ignoring reaction 'EX_cpd00051_b' since it already exists.
# Ignoring reaction 'EX_cpd00064_b' since it already exists.
# Ignoring reaction 'EX_cpd00100_b' since it already exists.
# Ignoring reaction 'EX_cpd00034_b' since it already exists.
# Ignoring reaction 'EX_cpd10516_b' since it already exists.
# Ignoring reaction 'EX_cpd00027_b' since it already exists.
# Ignoring reaction 'EX_cpd00122_b' since it already exists.
# Ignoring reaction 'EX_cpd00254_b' since it already exists.
# Ignoring reaction 'EX_cpd00205_b' since it already exists.
# Ignoring reaction 'EX_cpd00048_b' since it already exists.
# Ignoring reaction 'EX_cpd00030_b' since it already exists.
# Ignoring reaction 'EX_cpd00149_b' since it already exists.
# Ignoring reaction 'EX_cpd00226_b' since it already exists.
# Ignoring reaction 'EX_cpd00007_b' since it already exists.
# Ignoring reaction 'EX_cpd00011_b' since it already exists.
# Ignoring reaction 'EX_cpd00063_b' since it already exists.
# Ignoring reaction 'EX_cpd00009_b' since it already exists.
# Ignoring reaction 'EX_cpd00099_b' since it already exists.
# 1576
# Ignoring reaction 'EX_cpd00067_e0' since it already exists.
# Ignoring reaction 'EX_cpd04097_e0' since it already exists.
# Ignoring reaction 'EX_cpd01030_e0' since it already exists.
# Ignoring reaction 'EX_cpd01012_e0' since it already exists.
# Ignoring reaction 'EX_cpd00208_e0' since it already exists.
# Ignoring reaction 'EX_cpd00276_e0' since it already exists.
# Ignoring reaction 'EX_cpd00082_e0' since it already exists.
# Ignoring reaction 'EX_cpd00001_e0' since it already exists.
# Ignoring reaction 'EX_cpd00971_e0' since it already exists.
# Ignoring reaction 'EX_cpd00058_e0' since it already exists.
# Ignoring reaction 'EX_cpd00314_e0' since it already exists.
# Ignoring reaction 'EX_cpd00013_e0' since it already exists.
# Ignoring reaction 'EX_cpd00051_e0' since it already exists.
# Ignoring reaction 'EX_cpd00064_e0' since it already exists.
# Ignoring reaction 'EX_cpd00179_e0' since it already exists.
# Ignoring reaction 'EX_cpd00100_e0' since it already exists.
# Ignoring reaction 'EX_cpd00034_e0' since it already exists.
# Ignoring reaction 'EX_cpd10516_e0' since it already exists.
# Ignoring reaction 'EX_cpd00027_e0' since it already exists.
# Ignoring reaction 'EX_cpd00076_e0' since it already exists.
# Ignoring reaction 'EX_cpd01171_e0' since it already exists.
# Ignoring reaction 'EX_cpd00122_e0' since it already exists.
# Ignoring reaction 'EX_cpd03696_e0' since it already exists.
# Ignoring reaction 'EX_cpd00588_e0' since it already exists.
# Ignoring reaction 'EX_cpd00254_e0' since it already exists.
# Ignoring reaction 'EX_cpd00205_e0' since it already exists.
# Ignoring reaction 'EX_cpd00138_e0' since it already exists.
# Ignoring reaction 'EX_cpd00048_e0' since it already exists.
# Ignoring reaction 'EX_cpd00030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00149_e0' since it already exists.
# Ignoring reaction 'EX_cpd00531_e0' since it already exists.
# Ignoring reaction 'EX_cpd00794_e0' since it already exists.
# Ignoring reaction 'EX_cpd00226_e0' since it already exists.
# Ignoring reaction 'EX_cpd00104_e0' since it already exists.
# Ignoring reaction 'EX_cpd00007_e0' since it already exists.
# Ignoring reaction 'EX_cpd00305_e0' since it already exists.
# Ignoring reaction 'EX_cpd00011_e0' since it already exists.
# Ignoring reaction 'EX_cpd00063_e0' since it already exists.
# Ignoring reaction 'EX_cpd00009_e0' since it already exists.
# Ignoring reaction 'EX_cpd00099_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_b' since it already exists.
# 1259
# 2768
# 2805
# 1591
# 1259
# 2770
# 2806
# 1591

# %% [markdown]
# Reconstruction of pairwise community model- GCM_P4_P5

# %%
##13Reconstruction of pairwise community model- GCM_P4_P5##

import cobra
import sys
import os

model1 = cobra.io.read_sbml_model(r'Final_GEM/bsp_P5.xml')
model2 = cobra.io.read_sbml_model(r'Final_GEM/osp_P4.xml')

print(len(model1.reactions))
print(len(model1.metabolites))
print(len(model1.genes))

#optimising the value#
solution=model1.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model1)

print(len(model2.reactions))
print(len(model2.metabolites))
print(len(model2.genes))

#optimising the value#
solution=model2.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model2)####use Jupyter notebook##

for i in model2.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"osp"
        i.id=j
        i.compartment="c0osp"

for i in model1.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"bsp"
        i.id=j
        i.compartment="c0bsp"

count=0
for i in model2.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"osp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"bsp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"osp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"bsp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"osp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"bsp"
        i.id=j
        count=count+1
print(count)

from cobra import Model, Reaction, Metabolite
model = Model('community_model5')
count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model1.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model2.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

from cobra import Metabolite
cpd11416_c0 = Metabolite(
    'cpd11416_c0',
    name='Complete_Biomass',
    compartment='c0'

    )

from cobra import Metabolite
cpd11416_b = Metabolite(
    'cpd11416_b',
    name='Complete_Biomass',
    compartment='e0'
    )

reaction = Reaction('Bio1')
reaction.name = ('Community_biomass')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({model2.metabolites.get_by_id("cpd11416_c0osp"): -0.18,
                          model1.metabolites.get_by_id("cpd11416_c0bsp"): -0.82,
                          cpd11416_c0: 1
                         })

        
reaction.reaction
model.add_reactions([reaction])
print(count)

reaction = Reaction('EX_cpd11416_c0')
reaction.name = ('EX_cpd11416_c0')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({
                          model.metabolites.get_by_id("cpd11416_c0"): -1,
                          cpd11416_b: 1
                        })

        
reaction.reaction
model.add_reactions([reaction])

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

model.objective = 'Bio1'

print('Community model has been reconstructed')
print('Model objective Bio1: ', model.slim_optimize())

cobra.io.write_sbml_model(model,'Output_GCM/GCM_P4_P5.xml')

F = model.optimize()
flux_p4_p5=F.fluxes
flux_p4_p5.to_csv("Output_FBA/FBA_p4_p5.csv")
# Out:
# 1489
# 1500
# 1562
# 1559
# 1594
# 2446
# 1361
# 1312
# 1
# 1
# 3
# 1
# Ignoring reaction 'EX_cpd11416_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_b' since it already exists.
# Ignoring reaction 'EX_cpd11582_b' since it already exists.
# Ignoring reaction 'EX_cpd00276_b' since it already exists.
# Ignoring reaction 'EX_cpd00082_b' since it already exists.
# Ignoring reaction 'EX_cpd00001_b' since it already exists.
# Ignoring reaction 'EX_cpd00023_b' since it already exists.
# Ignoring reaction 'EX_cpd00058_b' since it already exists.
# Ignoring reaction 'EX_cpd00314_b' since it already exists.
# Ignoring reaction 'EX_cpd01017_b' since it already exists.
# Ignoring reaction 'EX_cpd00797_b' since it already exists.
# Ignoring reaction 'EX_cpd00051_b' since it already exists.
# Ignoring reaction 'EX_cpd00064_b' since it already exists.
# Ignoring reaction 'EX_cpd00100_b' since it already exists.
# Ignoring reaction 'EX_cpd11591_b' since it already exists.
# Ignoring reaction 'EX_cpd00009_b' since it already exists.
# Ignoring reaction 'EX_cpd00034_b' since it already exists.
# Ignoring reaction 'EX_cpd00076_b' since it already exists.
# Ignoring reaction 'EX_cpd15605_b' since it already exists.
# Ignoring reaction 'EX_cpd00264_b' since it already exists.
# Ignoring reaction 'EX_cpd00122_b' since it already exists.
# Ignoring reaction 'EX_cpd00118_b' since it already exists.
# Ignoring reaction 'EX_cpd00309_b' since it already exists.
# Ignoring reaction 'EX_cpd00220_b' since it already exists.
# Ignoring reaction 'EX_cpd00254_b' since it already exists.
# Ignoring reaction 'EX_cpd00138_b' since it already exists.
# Ignoring reaction 'EX_cpd15606_b' since it already exists.
# Ignoring reaction 'EX_cpd10516_b' since it already exists.
# Ignoring reaction 'EX_cpd00149_b' since it already exists.
# Ignoring reaction 'EX_cpd11583_b' since it already exists.
# Ignoring reaction 'EX_cpd00027_b' since it already exists.
# Ignoring reaction 'EX_cpd00794_b' since it already exists.
# Ignoring reaction 'EX_cpd00226_b' since it already exists.
# Ignoring reaction 'EX_cpd00048_b' since it already exists.
# Ignoring reaction 'EX_cpd00007_b' since it already exists.
# Ignoring reaction 'EX_cpd11587_b' since it already exists.
# Ignoring reaction 'EX_cpd00092_b' since it already exists.
# Ignoring reaction 'EX_cpd11581_b' since it already exists.
# Ignoring reaction 'EX_cpd11584_b' since it already exists.
# Ignoring reaction 'EX_cpd00039_b' since it already exists.
# Ignoring reaction 'EX_cpd00011_b' since it already exists.
# Ignoring reaction 'EX_cpd00030_b' since it already exists.
# Ignoring reaction 'EX_cpd00013_b' since it already exists.
# Ignoring reaction 'EX_cpd00205_b' since it already exists.
# Ignoring reaction 'EX_cpd00099_b' since it already exists.
# Ignoring reaction 'EX_cpd00063_b' since it already exists.
# 1488
# Ignoring reaction 'EX_cpd00067_e0' since it already exists.
# Ignoring reaction 'EX_cpd11576_e0' since it already exists.
# Ignoring reaction 'EX_cpd04097_e0' since it already exists.
# Ignoring reaction 'EX_cpd11585_e0' since it already exists.
# Ignoring reaction 'EX_cpd11582_e0' since it already exists.
# Ignoring reaction 'EX_cpd11586_e0' since it already exists.
# Ignoring reaction 'EX_cpd01030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00971_e0' since it already exists.
# Ignoring reaction 'EX_cpd01012_e0' since it already exists.
# Ignoring reaction 'EX_cpd00276_e0' since it already exists.
# Ignoring reaction 'EX_cpd00082_e0' since it already exists.
# Ignoring reaction 'EX_cpd00001_e0' since it already exists.
# Ignoring reaction 'EX_cpd00023_e0' since it already exists.
# Ignoring reaction 'EX_cpd00058_e0' since it already exists.
# Ignoring reaction 'EX_cpd00314_e0' since it already exists.
# Ignoring reaction 'EX_cpd01017_e0' since it already exists.
# Ignoring reaction 'EX_cpd00797_e0' since it already exists.
# Ignoring reaction 'EX_cpd00051_e0' since it already exists.
# Ignoring reaction 'EX_cpd00064_e0' since it already exists.
# Ignoring reaction 'EX_cpd00179_e0' since it already exists.
# Ignoring reaction 'EX_cpd00100_e0' since it already exists.
# Ignoring reaction 'EX_cpd11591_e0' since it already exists.
# Ignoring reaction 'EX_cpd00009_e0' since it already exists.
# Ignoring reaction 'EX_cpd00060_e0' since it already exists.
# Ignoring reaction 'EX_cpd00034_e0' since it already exists.
# Ignoring reaction 'EX_cpd11593_e0' since it already exists.
# Ignoring reaction 'EX_cpd00076_e0' since it already exists.
# Ignoring reaction 'EX_cpd01171_e0' since it already exists.
# Ignoring reaction 'EX_cpd15605_e0' since it already exists.
# Ignoring reaction 'EX_cpd00264_e0' since it already exists.
# Ignoring reaction 'EX_cpd03724_e0' since it already exists.
# Ignoring reaction 'EX_cpd00637_e0' since it already exists.
# Ignoring reaction 'EX_cpd00122_e0' since it already exists.
# Ignoring reaction 'EX_cpd15603_e0' since it already exists.
# Ignoring reaction 'EX_cpd03696_e0' since it already exists.
# Ignoring reaction 'EX_cpd00118_e0' since it already exists.
# Ignoring reaction 'EX_cpd00309_e0' since it already exists.
# Ignoring reaction 'EX_cpd11580_e0' since it already exists.
# Ignoring reaction 'EX_cpd00220_e0' since it already exists.
# Ignoring reaction 'EX_cpd00588_e0' since it already exists.
# Ignoring reaction 'EX_cpd00254_e0' since it already exists.
# Ignoring reaction 'EX_cpd00138_e0' since it already exists.
# Ignoring reaction 'EX_cpd15606_e0' since it already exists.
# Ignoring reaction 'EX_cpd10516_e0' since it already exists.
# Ignoring reaction 'EX_cpd00149_e0' since it already exists.
# Ignoring reaction 'EX_cpd01914_e0' since it already exists.
# Ignoring reaction 'EX_cpd00531_e0' since it already exists.
# Ignoring reaction 'EX_cpd11583_e0' since it already exists.
# Ignoring reaction 'EX_cpd11589_e0' since it already exists.
# Ignoring reaction 'EX_cpd00027_e0' since it already exists.
# Ignoring reaction 'EX_cpd00794_e0' since it already exists.
# Ignoring reaction 'EX_cpd00226_e0' since it already exists.
# Ignoring reaction 'EX_cpd11588_e0' since it already exists.
# Ignoring reaction 'EX_cpd00048_e0' since it already exists.
# Ignoring reaction 'EX_cpd15604_e0' since it already exists.
# Ignoring reaction 'EX_cpd00104_e0' since it already exists.
# Ignoring reaction 'EX_cpd00007_e0' since it already exists.
# Ignoring reaction 'EX_cpd11592_e0' since it already exists.
# Ignoring reaction 'EX_cpd11587_e0' since it already exists.
# Ignoring reaction 'EX_cpd00092_e0' since it already exists.
# Ignoring reaction 'EX_cpd11590_e0' since it already exists.
# Ignoring reaction 'EX_cpd11581_e0' since it already exists.
# Ignoring reaction 'EX_cpd11584_e0' since it already exists.
# Ignoring reaction 'EX_cpd00158_e0' since it already exists.
# Ignoring reaction 'EX_cpd00039_e0' since it already exists.
# Ignoring reaction 'EX_cpd00011_e0' since it already exists.
# Ignoring reaction 'EX_cpd00030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00013_e0' since it already exists.
# Ignoring reaction 'EX_cpd00205_e0' since it already exists.
# Ignoring reaction 'EX_cpd00099_e0' since it already exists.
# Ignoring reaction 'EX_cpd00063_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_b' since it already exists.
# 1558
# 2927
# 2947
# 2003
# 1558
# 2929
# 2948
# 2003

# %% [markdown]
# Reconstruction of pairwise community model- GCM_P4_P6

# %%
##14Reconstruction of pairwise community model- GCM_P4_P6##

import cobra
import sys
import os

model1 = cobra.io.read_sbml_model(r'Final_GEM/nc_P6.xml')
model2 = cobra.io.read_sbml_model(r'Final_GEM/osp_P4.xml')

print(len(model1.reactions))
print(len(model1.metabolites))
print(len(model1.genes))

#optimising the value#
solution=model1.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model1)

print(len(model2.reactions))
print(len(model2.metabolites))
print(len(model2.genes))

#optimising the value#
solution=model2.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model2)####use Jupyter notebook##


for i in model1.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"nc"
        i.id=j
        i.compartment="c0nc"

for i in model2.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"osp"
        i.id=j
        i.compartment="c0osp"

count=0
for i in model1.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"nc"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"osp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"ns"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"osp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"nc"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"osp"
        i.id=j
        count=count+1
print(count)

from cobra import Model, Reaction, Metabolite
model = Model('community_model4')
count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model1.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model2.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

from cobra import Metabolite
cpd11416_c0 = Metabolite(
    'cpd11416_c0',
    name='Complete_Biomass',
    compartment='c0'

    )

from cobra import Metabolite
cpd11416_b = Metabolite(
    'cpd11416_b',
    name='Complete_Biomass',
    compartment='e0'
    )

reaction = Reaction('Bio1')
reaction.name = ('Community_biomass')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({model1.metabolites.get_by_id("cpd11416_c0nc"): -0.72,
                          model2.metabolites.get_by_id("cpd11416_c0osp"): -0.28,
                          cpd11416_c0: 1
                         })

        
reaction.reaction
model.add_reactions([reaction])
print(count)

reaction = Reaction('EX_cpd11416_c0')
reaction.name = ('EX_cpd11416_c0')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({
                          model.metabolites.get_by_id("cpd11416_c0"): -1,
                          cpd11416_b: 1
                        })

        
reaction.reaction
model.add_reactions([reaction])

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

model.objective = 'Bio1'

print('Community model has been reconstructed')
print('Model objective Bio1: ', model.slim_optimize())

cobra.io.write_sbml_model(model,'Output_GCM/GCM_P4_P6.xml')

F = model.optimize()
flux_p4_p6=F.fluxes
flux_p4_p6.to_csv("Output_FBA/FBA_p4_p6.csv")
# Out:
# 1577
# 1563
# 1942
# 1559
# 1594
# 2446
# 1366
# 1361
# 1
# 1
# 2
# 3
# Ignoring reaction 'EX_cpd11416_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_b' since it already exists.
# Ignoring reaction 'EX_cpd00182_b' since it already exists.
# Ignoring reaction 'EX_cpd00412_b' since it already exists.
# Ignoring reaction 'EX_cpd11582_b' since it already exists.
# Ignoring reaction 'EX_cpd00246_b' since it already exists.
# Ignoring reaction 'EX_cpd00276_b' since it already exists.
# Ignoring reaction 'EX_cpd00082_b' since it already exists.
# Ignoring reaction 'EX_cpd00080_b' since it already exists.
# Ignoring reaction 'EX_cpd00001_b' since it already exists.
# Ignoring reaction 'EX_cpd00367_b' since it already exists.
# Ignoring reaction 'EX_cpd00058_b' since it already exists.
# Ignoring reaction 'EX_cpd00184_b' since it already exists.
# Ignoring reaction 'EX_cpd00314_b' since it already exists.
# Ignoring reaction 'EX_cpd01017_b' since it already exists.
# Ignoring reaction 'EX_cpd00051_b' since it already exists.
# Ignoring reaction 'EX_cpd00064_b' since it already exists.
# Ignoring reaction 'EX_cpd00100_b' since it already exists.
# Ignoring reaction 'EX_cpd11591_b' since it already exists.
# Ignoring reaction 'EX_cpd00009_b' since it already exists.
# Ignoring reaction 'EX_cpd00034_b' since it already exists.
# Ignoring reaction 'EX_cpd00249_b' since it already exists.
# Ignoring reaction 'EX_cpd00654_b' since it already exists.
# Ignoring reaction 'EX_cpd00076_b' since it already exists.
# Ignoring reaction 'EX_cpd03198_b' since it already exists.
# Ignoring reaction 'EX_cpd15605_b' since it already exists.
# Ignoring reaction 'EX_cpd00264_b' since it already exists.
# Ignoring reaction 'EX_cpd00122_b' since it already exists.
# Ignoring reaction 'EX_cpd00277_b' since it already exists.
# Ignoring reaction 'EX_cpd00118_b' since it already exists.
# Ignoring reaction 'EX_cpd00309_b' since it already exists.
# Ignoring reaction 'EX_cpd00220_b' since it already exists.
# Ignoring reaction 'EX_cpd03279_b' since it already exists.
# Ignoring reaction 'EX_cpd00307_b' since it already exists.
# Ignoring reaction 'EX_cpd00254_b' since it already exists.
# Ignoring reaction 'EX_cpd00138_b' since it already exists.
# Ignoring reaction 'EX_cpd00540_b' since it already exists.
# Ignoring reaction 'EX_cpd15606_b' since it already exists.
# Ignoring reaction 'EX_cpd10516_b' since it already exists.
# Ignoring reaction 'EX_cpd00149_b' since it already exists.
# Ignoring reaction 'EX_cpd11583_b' since it already exists.
# Ignoring reaction 'EX_cpd00027_b' since it already exists.
# Ignoring reaction 'EX_cpd00794_b' since it already exists.
# Ignoring reaction 'EX_cpd00226_b' since it already exists.
# Ignoring reaction 'EX_cpd00048_b' since it already exists.
# Ignoring reaction 'EX_cpd00007_b' since it already exists.
# Ignoring reaction 'EX_cpd11587_b' since it already exists.
# Ignoring reaction 'EX_cpd00092_b' since it already exists.
# Ignoring reaction 'EX_cpd11581_b' since it already exists.
# Ignoring reaction 'EX_cpd11584_b' since it already exists.
# Ignoring reaction 'EX_cpd00039_b' since it already exists.
# Ignoring reaction 'EX_cpd00011_b' since it already exists.
# Ignoring reaction 'EX_cpd00030_b' since it already exists.
# Ignoring reaction 'EX_cpd00013_b' since it already exists.
# Ignoring reaction 'EX_cpd00205_b' since it already exists.
# Ignoring reaction 'EX_cpd00099_b' since it already exists.
# Ignoring reaction 'EX_cpd00063_b' since it already exists.
# 1576
# Ignoring reaction 'EX_cpd00067_e0' since it already exists.
# Ignoring reaction 'EX_cpd00182_e0' since it already exists.
# Ignoring reaction 'EX_cpd11576_e0' since it already exists.
# Ignoring reaction 'EX_cpd04097_e0' since it already exists.
# Ignoring reaction 'EX_cpd11597_e0' since it already exists.
# Ignoring reaction 'EX_cpd11585_e0' since it already exists.
# Ignoring reaction 'EX_cpd00412_e0' since it already exists.
# Ignoring reaction 'EX_cpd11582_e0' since it already exists.
# Ignoring reaction 'EX_cpd11586_e0' since it already exists.
# Ignoring reaction 'EX_cpd01030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00971_e0' since it already exists.
# Ignoring reaction 'EX_cpd01012_e0' since it already exists.
# Ignoring reaction 'EX_cpd00246_e0' since it already exists.
# Ignoring reaction 'EX_cpd00276_e0' since it already exists.
# Ignoring reaction 'EX_cpd00082_e0' since it already exists.
# Ignoring reaction 'EX_cpd00080_e0' since it already exists.
# Ignoring reaction 'EX_cpd00001_e0' since it already exists.
# Ignoring reaction 'EX_cpd00367_e0' since it already exists.
# Ignoring reaction 'EX_cpd00058_e0' since it already exists.
# Ignoring reaction 'EX_cpd00184_e0' since it already exists.
# Ignoring reaction 'EX_cpd00314_e0' since it already exists.
# Ignoring reaction 'EX_cpd01017_e0' since it already exists.
# Ignoring reaction 'EX_cpd00051_e0' since it already exists.
# Ignoring reaction 'EX_cpd00064_e0' since it already exists.
# Ignoring reaction 'EX_cpd00179_e0' since it already exists.
# Ignoring reaction 'EX_cpd00100_e0' since it already exists.
# Ignoring reaction 'EX_cpd11591_e0' since it already exists.
# Ignoring reaction 'EX_cpd00009_e0' since it already exists.
# Ignoring reaction 'EX_cpd00060_e0' since it already exists.
# Ignoring reaction 'EX_cpd00438_e0' since it already exists.
# Ignoring reaction 'EX_cpd00034_e0' since it already exists.
# Ignoring reaction 'EX_cpd00249_e0' since it already exists.
# Ignoring reaction 'EX_cpd11593_e0' since it already exists.
# Ignoring reaction 'EX_cpd00654_e0' since it already exists.
# Ignoring reaction 'EX_cpd00076_e0' since it already exists.
# Ignoring reaction 'EX_cpd03198_e0' since it already exists.
# Ignoring reaction 'EX_cpd01171_e0' since it already exists.
# Ignoring reaction 'EX_cpd00176_e0' since it already exists.
# Ignoring reaction 'EX_cpd15605_e0' since it already exists.
# Ignoring reaction 'EX_cpd00264_e0' since it already exists.
# Ignoring reaction 'EX_cpd00154_e0' since it already exists.
# Ignoring reaction 'EX_cpd00637_e0' since it already exists.
# Ignoring reaction 'EX_cpd00122_e0' since it already exists.
# Ignoring reaction 'EX_cpd08306_e0' since it already exists.
# Ignoring reaction 'EX_cpd15603_e0' since it already exists.
# Ignoring reaction 'EX_cpd03696_e0' since it already exists.
# Ignoring reaction 'EX_cpd00277_e0' since it already exists.
# Ignoring reaction 'EX_cpd00118_e0' since it already exists.
# Ignoring reaction 'EX_cpd00309_e0' since it already exists.
# Ignoring reaction 'EX_cpd11580_e0' since it already exists.
# Ignoring reaction 'EX_cpd01092_e0' since it already exists.
# Ignoring reaction 'EX_cpd00220_e0' since it already exists.
# Ignoring reaction 'EX_cpd03279_e0' since it already exists.
# Ignoring reaction 'EX_cpd00588_e0' since it already exists.
# Ignoring reaction 'EX_cpd00307_e0' since it already exists.
# Ignoring reaction 'EX_cpd00653_e0' since it already exists.
# Ignoring reaction 'EX_cpd00254_e0' since it already exists.
# Ignoring reaction 'EX_cpd00138_e0' since it already exists.
# Ignoring reaction 'EX_cpd00305_e0' since it already exists.
# Ignoring reaction 'EX_cpd00540_e0' since it already exists.
# Ignoring reaction 'EX_cpd15606_e0' since it already exists.
# Ignoring reaction 'EX_cpd10516_e0' since it already exists.
# Ignoring reaction 'EX_cpd00149_e0' since it already exists.
# Ignoring reaction 'EX_cpd01914_e0' since it already exists.
# Ignoring reaction 'EX_cpd00531_e0' since it already exists.
# Ignoring reaction 'EX_cpd11583_e0' since it already exists.
# Ignoring reaction 'EX_cpd11589_e0' since it already exists.
# Ignoring reaction 'EX_cpd00027_e0' since it already exists.
# Ignoring reaction 'EX_cpd00794_e0' since it already exists.
# Ignoring reaction 'EX_cpd00226_e0' since it already exists.
# Ignoring reaction 'EX_cpd08305_e0' since it already exists.
# Ignoring reaction 'EX_cpd11588_e0' since it already exists.
# Ignoring reaction 'EX_cpd00048_e0' since it already exists.
# Ignoring reaction 'EX_cpd15604_e0' since it already exists.
# Ignoring reaction 'EX_cpd00104_e0' since it already exists.
# Ignoring reaction 'EX_cpd00007_e0' since it already exists.
# Ignoring reaction 'EX_cpd11592_e0' since it already exists.
# Ignoring reaction 'EX_cpd11587_e0' since it already exists.
# Ignoring reaction 'EX_cpd00092_e0' since it already exists.
# Ignoring reaction 'EX_cpd11590_e0' since it already exists.
# Ignoring reaction 'EX_cpd11581_e0' since it already exists.
# Ignoring reaction 'EX_cpd11584_e0' since it already exists.
# Ignoring reaction 'EX_cpd00158_e0' since it already exists.
# Ignoring reaction 'EX_cpd00039_e0' since it already exists.
# Ignoring reaction 'EX_cpd00011_e0' since it already exists.
# Ignoring reaction 'EX_cpd00030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00013_e0' since it already exists.
# Ignoring reaction 'EX_cpd00205_e0' since it already exists.
# Ignoring reaction 'EX_cpd00099_e0' since it already exists.
# Ignoring reaction 'EX_cpd00063_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_b' since it already exists.
# 1558
# 2985
# 2971
# 2193
# 1558
# 2987
# 2972
# 2193

# %% [markdown]
# Reconstruction of pairwise community model- GCM_P5_P6

# %%
##15Reconstruction of pairwise community model- GCM_P5_P6##

import cobra
import sys
import os

model1 = cobra.io.read_sbml_model(r'Final_GEM/bsp_P5.xml')
model2 = cobra.io.read_sbml_model(r'Final_GEM/nc_P6.xml')

print(len(model1.reactions))
print(len(model1.metabolites))
print(len(model1.genes))

#optimising the value#
solution=model1.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model1)

print(len(model2.reactions))
print(len(model2.metabolites))
print(len(model2.genes))

#optimising the value#
solution=model2.optimize()
solution.objective_value

cobra.flux_analysis.find_blocked_reactions(model2)####use Jupyter notebook##


for i in model1.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"bsp"
        i.id=j
        i.compartment="c0bsp"

for i in model2.metabolites:
    if(str(i)[-2]=="c"):
        j=str(i)+"nc"
        i.id=j
        i.compartment="c0nc"

count=0
for i in model1.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"bsp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)[0]=="r"):
        j=str(i.id)+"nc"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"bsp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="bio1"):
        j=str(i.id)+"nc"
        i.id=j
        count=count+1
print(count)

count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"bsp"
        i.id=j
        count=count+1
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):continue
    if(str(i.id)[0]=="E" and str(i.id)[-2]=="c"):
        j=str(i.id)+"nc"
        i.id=j
        count=count+1
print(count)

from cobra import Model, Reaction, Metabolite
model = Model('community_model4')
count=0
for i in model1.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model1.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

count=0
for i in model2.reactions:
    if(str(i.id)=="EX_cpd11416_c0"):
        continue
    reaction=model2.reactions.get_by_id(str(i.id))
    reaction.reaction
    count=count+1
    model.add_reactions([reaction])
        
print(count)

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

from cobra import Metabolite
cpd11416_c0 = Metabolite(
    'cpd11416_c0',
    name='Complete_Biomass',
    compartment='c0'

    )

from cobra import Metabolite
cpd11416_b = Metabolite(
    'cpd11416_b',
    name='Complete_Biomass',
    compartment='e0'
    )

reaction = Reaction('Bio1')
reaction.name = ('Community_biomass')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({model1.metabolites.get_by_id("cpd11416_c0bsp"): -0.64,
                          model2.metabolites.get_by_id("cpd11416_c0nc"): -0.36,
                          cpd11416_c0: 1
                         })

        
reaction.reaction
model.add_reactions([reaction])
print(count)

reaction = Reaction('EX_cpd11416_c0')
reaction.name = ('EX_cpd11416_c0')
reaction.lower_bound = 0
reaction.upper_bound = 1000

reaction.add_metabolites({
                          model.metabolites.get_by_id("cpd11416_c0"): -1,
                          cpd11416_b: 1
                        })

        
reaction.reaction
model.add_reactions([reaction])

print(len(model.reactions))
print(len(model.metabolites))
print(len(model.genes))

model.objective = 'Bio1'
print('Community model has been reconstructed')
print('Model objective Bio1: ', model.slim_optimize())

cobra.io.write_sbml_model(model,'Output_GCM/GCM_P5_P6.xml')

F = model.optimize()
flux_p5_p6=F.fluxes
flux_p5_p6.to_csv("Output_FBA/FBA_p5_p6.csv")
# Out:
# 1489
# 1500
# 1562
# 1577
# 1563
# 1942
# 1312
# 1366
# 1
# 1
# 1
# 2
# Ignoring reaction 'EX_cpd11416_b' since it already exists.
# Ignoring reaction 'EX_cpd00067_b' since it already exists.
# Ignoring reaction 'EX_cpd11576_b' since it already exists.
# Ignoring reaction 'EX_cpd04097_b' since it already exists.
# Ignoring reaction 'EX_cpd11585_b' since it already exists.
# Ignoring reaction 'EX_cpd11582_b' since it already exists.
# Ignoring reaction 'EX_cpd00012_b' since it already exists.
# Ignoring reaction 'EX_cpd11586_b' since it already exists.
# Ignoring reaction 'EX_cpd01030_b' since it already exists.
# Ignoring reaction 'EX_cpd01012_b' since it already exists.
# Ignoring reaction 'EX_cpd00635_b' since it already exists.
# Ignoring reaction 'EX_cpd00276_b' since it already exists.
# Ignoring reaction 'EX_cpd00082_b' since it already exists.
# Ignoring reaction 'EX_cpd00001_b' since it already exists.
# Ignoring reaction 'EX_cpd00058_b' since it already exists.
# Ignoring reaction 'EX_cpd00314_b' since it already exists.
# Ignoring reaction 'EX_cpd01017_b' since it already exists.
# Ignoring reaction 'EX_cpd00013_b' since it already exists.
# Ignoring reaction 'EX_cpd00051_b' since it already exists.
# Ignoring reaction 'EX_cpd00064_b' since it already exists.
# Ignoring reaction 'EX_cpd00179_b' since it already exists.
# Ignoring reaction 'EX_cpd00100_b' since it already exists.
# Ignoring reaction 'EX_cpd11591_b' since it already exists.
# Ignoring reaction 'EX_cpd00060_b' since it already exists.
# Ignoring reaction 'EX_cpd11593_b' since it already exists.
# Ignoring reaction 'EX_cpd00076_b' since it already exists.
# Ignoring reaction 'EX_cpd01171_b' since it already exists.
# Ignoring reaction 'EX_cpd15605_b' since it already exists.
# Ignoring reaction 'EX_cpd00264_b' since it already exists.
# Ignoring reaction 'EX_cpd00637_b' since it already exists.
# Ignoring reaction 'EX_cpd00122_b' since it already exists.
# Ignoring reaction 'EX_cpd00035_b' since it already exists.
# Ignoring reaction 'EX_cpd15603_b' since it already exists.
# Ignoring reaction 'EX_cpd03696_b' since it already exists.
# Ignoring reaction 'EX_cpd00118_b' since it already exists.
# Ignoring reaction 'EX_cpd00309_b' since it already exists.
# Ignoring reaction 'EX_cpd11580_b' since it already exists.
# Ignoring reaction 'EX_cpd00220_b' since it already exists.
# Ignoring reaction 'EX_cpd00588_b' since it already exists.
# Ignoring reaction 'EX_cpd00423_b' since it already exists.
# Ignoring reaction 'EX_cpd00117_b' since it already exists.
# Ignoring reaction 'EX_cpd00254_b' since it already exists.
# Ignoring reaction 'EX_cpd00138_b' since it already exists.
# Ignoring reaction 'EX_cpd00009_b' since it already exists.
# Ignoring reaction 'EX_cpd15606_b' since it already exists.
# Ignoring reaction 'EX_cpd10516_b' since it already exists.
# Ignoring reaction 'EX_cpd00971_b' since it already exists.
# Ignoring reaction 'EX_cpd00030_b' since it already exists.
# Ignoring reaction 'EX_cpd00149_b' since it already exists.
# Ignoring reaction 'EX_cpd01914_b' since it already exists.
# Ignoring reaction 'EX_cpd00531_b' since it already exists.
# Ignoring reaction 'EX_cpd11583_b' since it already exists.
# Ignoring reaction 'EX_cpd11589_b' since it already exists.
# Ignoring reaction 'EX_cpd00027_b' since it already exists.
# Ignoring reaction 'EX_cpd00794_b' since it already exists.
# Ignoring reaction 'EX_cpd00226_b' since it already exists.
# Ignoring reaction 'EX_cpd11588_b' since it already exists.
# Ignoring reaction 'EX_cpd00048_b' since it already exists.
# Ignoring reaction 'EX_cpd15604_b' since it already exists.
# Ignoring reaction 'EX_cpd00104_b' since it already exists.
# Ignoring reaction 'EX_cpd00007_b' since it already exists.
# Ignoring reaction 'EX_cpd03424_b' since it already exists.
# Ignoring reaction 'EX_cpd11592_b' since it already exists.
# Ignoring reaction 'EX_cpd11587_b' since it already exists.
# Ignoring reaction 'EX_cpd00092_b' since it already exists.
# Ignoring reaction 'EX_cpd11590_b' since it already exists.
# Ignoring reaction 'EX_cpd11581_b' since it already exists.
# Ignoring reaction 'EX_cpd00205_b' since it already exists.
# Ignoring reaction 'EX_cpd11584_b' since it already exists.
# Ignoring reaction 'EX_cpd00158_b' since it already exists.
# Ignoring reaction 'EX_cpd00039_b' since it already exists.
# Ignoring reaction 'EX_cpd00011_b' since it already exists.
# Ignoring reaction 'EX_cpd00063_b' since it already exists.
# Ignoring reaction 'EX_cpd00034_b' since it already exists.
# Ignoring reaction 'EX_cpd00099_b' since it already exists.
# 1488
# Ignoring reaction 'EX_cpd00067_e0' since it already exists.
# Ignoring reaction 'EX_cpd11576_e0' since it already exists.
# Ignoring reaction 'EX_cpd04097_e0' since it already exists.
# Ignoring reaction 'EX_cpd11585_e0' since it already exists.
# Ignoring reaction 'EX_cpd11582_e0' since it already exists.
# Ignoring reaction 'EX_cpd00012_e0' since it already exists.
# Ignoring reaction 'EX_cpd11586_e0' since it already exists.
# Ignoring reaction 'EX_cpd01030_e0' since it already exists.
# Ignoring reaction 'EX_cpd01012_e0' since it already exists.
# Ignoring reaction 'EX_cpd00635_e0' since it already exists.
# Ignoring reaction 'EX_cpd00276_e0' since it already exists.
# Ignoring reaction 'EX_cpd00082_e0' since it already exists.
# Ignoring reaction 'EX_cpd00001_e0' since it already exists.
# Ignoring reaction 'EX_cpd00058_e0' since it already exists.
# Ignoring reaction 'EX_cpd00314_e0' since it already exists.
# Ignoring reaction 'EX_cpd01017_e0' since it already exists.
# Ignoring reaction 'EX_cpd00013_e0' since it already exists.
# Ignoring reaction 'EX_cpd00051_e0' since it already exists.
# Ignoring reaction 'EX_cpd00064_e0' since it already exists.
# Ignoring reaction 'EX_cpd00179_e0' since it already exists.
# Ignoring reaction 'EX_cpd00100_e0' since it already exists.
# Ignoring reaction 'EX_cpd11591_e0' since it already exists.
# Ignoring reaction 'EX_cpd00060_e0' since it already exists.
# Ignoring reaction 'EX_cpd11593_e0' since it already exists.
# Ignoring reaction 'EX_cpd00076_e0' since it already exists.
# Ignoring reaction 'EX_cpd01171_e0' since it already exists.
# Ignoring reaction 'EX_cpd15605_e0' since it already exists.
# Ignoring reaction 'EX_cpd00264_e0' since it already exists.
# Ignoring reaction 'EX_cpd00637_e0' since it already exists.
# Ignoring reaction 'EX_cpd00122_e0' since it already exists.
# Ignoring reaction 'EX_cpd00035_e0' since it already exists.
# Ignoring reaction 'EX_cpd15603_e0' since it already exists.
# Ignoring reaction 'EX_cpd03696_e0' since it already exists.
# Ignoring reaction 'EX_cpd00118_e0' since it already exists.
# Ignoring reaction 'EX_cpd00309_e0' since it already exists.
# Ignoring reaction 'EX_cpd11580_e0' since it already exists.
# Ignoring reaction 'EX_cpd00220_e0' since it already exists.
# Ignoring reaction 'EX_cpd00588_e0' since it already exists.
# Ignoring reaction 'EX_cpd00423_e0' since it already exists.
# Ignoring reaction 'EX_cpd00117_e0' since it already exists.
# Ignoring reaction 'EX_cpd00254_e0' since it already exists.
# Ignoring reaction 'EX_cpd00138_e0' since it already exists.
# Ignoring reaction 'EX_cpd00009_e0' since it already exists.
# Ignoring reaction 'EX_cpd15606_e0' since it already exists.
# Ignoring reaction 'EX_cpd10516_e0' since it already exists.
# Ignoring reaction 'EX_cpd00971_e0' since it already exists.
# Ignoring reaction 'EX_cpd00030_e0' since it already exists.
# Ignoring reaction 'EX_cpd00149_e0' since it already exists.
# Ignoring reaction 'EX_cpd01914_e0' since it already exists.
# Ignoring reaction 'EX_cpd00531_e0' since it already exists.
# Ignoring reaction 'EX_cpd11583_e0' since it already exists.
# Ignoring reaction 'EX_cpd11589_e0' since it already exists.
# Ignoring reaction 'EX_cpd00027_e0' since it already exists.
# Ignoring reaction 'EX_cpd00794_e0' since it already exists.
# Ignoring reaction 'EX_cpd00226_e0' since it already exists.
# Ignoring reaction 'EX_cpd11588_e0' since it already exists.
# Ignoring reaction 'EX_cpd00048_e0' since it already exists.
# Ignoring reaction 'EX_cpd15604_e0' since it already exists.
# Ignoring reaction 'EX_cpd00104_e0' since it already exists.
# Ignoring reaction 'EX_cpd00007_e0' since it already exists.
# Ignoring reaction 'EX_cpd03424_e0' since it already exists.
# Ignoring reaction 'EX_cpd11592_e0' since it already exists.
# Ignoring reaction 'EX_cpd11587_e0' since it already exists.
# Ignoring reaction 'EX_cpd00092_e0' since it already exists.
# Ignoring reaction 'EX_cpd11590_e0' since it already exists.
# Ignoring reaction 'EX_cpd11581_e0' since it already exists.
# Ignoring reaction 'EX_cpd00205_e0' since it already exists.
# Ignoring reaction 'EX_cpd11584_e0' since it already exists.
# Ignoring reaction 'EX_cpd00158_e0' since it already exists.
# Ignoring reaction 'EX_cpd00039_e0' since it already exists.
# Ignoring reaction 'EX_cpd00011_e0' since it already exists.
# Ignoring reaction 'EX_cpd00063_e0' since it already exists.
# Ignoring reaction 'EX_cpd00034_e0' since it already exists.
# Ignoring reaction 'EX_cpd00099_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_e0' since it already exists.
# Ignoring reaction 'EX_cpd11746_b' since it already exists.
# 1576
# 2913
# 2911
# 1751
# 1576
# 2915
# 2912
# 1751
